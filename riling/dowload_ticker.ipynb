# %%
import bs4

# %%
_52_week_gainers_html = '<div class="tableContainer yf-j24h8w"><div class="table-container cs-regular tw-border-none yf-269l37"><table class="yf-269l37 bd"><thead class="yf-269l37"><tr class="yf-269l37"><th class="[&amp;_.symbol]:tw-text-md yf-269l37 so lpin shad"><div class="colCont yf-269l37"> Symbol</div></th><th class="leftAlignHeader yf-269l37 so"><div class="colCont yf-269l37"> Name</div></th><th class=" yf-269l37"><div class="colCont yf-269l37"> <span data-svelte-h="svelte-1uypmr0">&nbsp;</span></div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Price</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Change</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Change %</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Volume</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Avg Vol (3M)</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Market Cap</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> <div class="yf-10yevti"><span>P/E Ratio </span><span>(TTM) </span></div></div></th><th class="yf-269l37 so sorted"><div class="colCont yf-269l37"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z"></path></svg></div> <div class="yf-10yevti"><span>52 Wk </span><span>Change % </span></div></div></th><th class=" yf-269l37"><div class="colCont yf-269l37"> 52 Wk Range</div></th> </tr></thead> <tbody><tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Relevium Technologies Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:RLLVF" href="/quote/RLLVF/" title="Relevium Technologies Inc." data-rapid_p="24" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">RLLVF </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Relevium Technologies Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Relevium Technologies Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:RLLVF" href="/chart/RLLVF" aria-label="Advanced Chart" data-rapid_p="25" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="RLLVF chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="RLLVF" data-field="regularMarketPrice" data-trend="none" data-pricehint="4" data-value="0.006" active="">0.0060</fin-streamer> <div class="hide-desktop hide-mw "><fin-streamer data-test="colorChange" data-symbol="RLLVF" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0" active="">0.0000</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="RLLVF" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="4" data-value="0" active="">(0.00%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RLLVF" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0" data-tstyle="default" active=""><span class="">0.0000</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RLLVF" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0" data-tstyle="default" active=""><span class="">0.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RLLVF" data-field="regularMarketVolume" data-trend="none" data-pricehint="4" data-value="10000" active="">10,000</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1,807 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RLLVF" data-field="marketCap" data-trend="none" data-pricehint="4" data-value="5277408" active="">5.277M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RLLVF" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="5900" data-tstyle="default" active=""><span class="txt-positive">+5,900.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="AST SpaceMobile, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ASTS" href="/quote/ASTS/" title="AST SpaceMobile, Inc." data-rapid_p="26" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ASTS </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="AST SpaceMobile, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">AST SpaceMobile, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ASTS" href="/chart/ASTS" aria-label="Advanced Chart" data-rapid_p="27" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ASTS chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ASTS" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="23.76" active="">23.76</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="ASTS" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.30999947" active="">-0.31</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ASTS" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-1.287908" active="">(-1.29%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ASTS" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.30999947" data-tstyle="default" active=""><span class="txt-negative">-0.31</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ASTS" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-1.287908" data-tstyle="default" active=""><span class="txt-negative">-1.29%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ASTS" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="7878736" active="">7.879M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">11.964M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ASTS" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="7617954816" active="">7.618B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ASTS" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="919.7425" data-tstyle="default" active=""><span class="txt-positive">+919.74%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="GeneDx Holdings Corp." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:WGS" href="/quote/WGS/" title="GeneDx Holdings Corp." data-rapid_p="28" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">WGS </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="GeneDx Holdings Corp." class="leftAlignHeader yf-362rys enableMaxWidth">GeneDx Holdings Corp.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:WGS" href="/chart/WGS" aria-label="Advanced Chart" data-rapid_p="29" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="WGS chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="WGS" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="111.01" active="">111.01</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="WGS" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.6200027" active="">+1.62</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="WGS" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.4809424" active="">(+1.48%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="WGS" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.6200027" data-tstyle="default" active=""><span class="txt-positive">+1.62</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="WGS" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.4809424" data-tstyle="default" active=""><span class="txt-positive">+1.48%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="WGS" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="619179" active="">619,179</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.028M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="WGS" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3167292928" active="">3.167B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="WGS" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="909.18176" data-tstyle="default" active=""><span class="txt-positive">+909.18%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Safer Shot, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SAFS" href="/quote/SAFS/" title="Safer Shot, Inc." data-rapid_p="30" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SAFS </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Safer Shot, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Safer Shot, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SAFS" href="/chart/SAFS" aria-label="Advanced Chart" data-rapid_p="31" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SAFS chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SAFS" data-field="regularMarketPrice" data-trend="none" data-pricehint="4" data-value="0.0001" active="">0.0001</fin-streamer> <div class="hide-desktop hide-mw "><fin-streamer data-test="colorChange" data-symbol="SAFS" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0" active="">0.0000</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SAFS" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="4" data-value="0" active="">(0.00%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SAFS" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0" data-tstyle="default" active=""><span class="">0.0000</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SAFS" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0" data-tstyle="default" active=""><span class="">0.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SAFS" data-field="regularMarketVolume" data-trend="none" data-pricehint="4" data-value="280000" active="">280,000</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">0 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SAFS" data-field="marketCap" data-trend="none" data-pricehint="4" data-value="348275008" active="">348.275M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SAFS" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="900" data-tstyle="default" active=""><span class="txt-positive">+900.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Rigetti Computing, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:RGTI" href="/quote/RGTI/" title="Rigetti Computing, Inc." data-rapid_p="32" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">RGTI </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Rigetti Computing, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Rigetti Computing, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:RGTI" href="/chart/RGTI" aria-label="Advanced Chart" data-rapid_p="33" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="RGTI chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="RGTI" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="9.37" active="">9.37</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="RGTI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.069999695" active="">+0.07</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="RGTI" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.7526849" active="">(+0.75%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RGTI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.069999695" data-tstyle="default" active=""><span class="txt-positive">+0.07</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RGTI" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.7526849" data-tstyle="default" active=""><span class="txt-positive">+0.75%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RGTI" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="36524370" active="">36.524M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">60.744M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RGTI" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2678208256" active="">2.678B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RGTI" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="599.2537" data-tstyle="default" active=""><span class="txt-positive">+599.25%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Summit Therapeutics Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SMMT" href="/quote/SMMT/" title="Summit Therapeutics Inc." data-rapid_p="34" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SMMT </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Summit Therapeutics Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Summit Therapeutics Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SMMT" href="/chart/SMMT" aria-label="Advanced Chart" data-rapid_p="35" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SMMT chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SMMT" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="23.465" active="">23.47</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="SMMT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-13.235001" active="">-13.24</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SMMT" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-36.062668" active="">(-36.06%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SMMT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-13.235001" data-tstyle="default" active=""><span class="txt-negative">-13.24</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SMMT" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-36.062668" data-tstyle="default" active=""><span class="txt-negative">-36.06%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SMMT" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="24670509" active="">24.671M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.552M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SMMT" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="27072743424" active="">27.073B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SMMT" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="504.76804" data-tstyle="default" active=""><span class="txt-positive">+504.77%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Rocket Lab USA, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:RKLB" href="/quote/RKLB/" title="Rocket Lab USA, Inc." data-rapid_p="36" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">RKLB </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Rocket Lab USA, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Rocket Lab USA, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:RKLB" href="/chart/RKLB" aria-label="Advanced Chart" data-rapid_p="37" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="RKLB chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="RKLB" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="22.38" active="">22.38</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="RKLB" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.5" active="">+0.50</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="RKLB" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="2.285192" active="">(+2.29%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RKLB" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.5" data-tstyle="default" active=""><span class="txt-positive">+0.50</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RKLB" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="2.285192" data-tstyle="default" active=""><span class="txt-positive">+2.29%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RKLB" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="13775635" active="">13.776M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">17.836M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RKLB" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="10150336512" active="">10.15B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RKLB" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="488.9474" data-tstyle="default" active=""><span class="txt-positive">+488.95%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Palantir Technologies Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:PLTR" href="/quote/PLTR/" title="Palantir Technologies Inc." data-rapid_p="38" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">PLTR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Palantir Technologies Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Palantir Technologies Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:PLTR" href="/chart/PLTR" aria-label="Advanced Chart" data-rapid_p="39" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="PLTR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="PLTR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="112.78" active="">112.78</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="PLTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="5" active="">+5.00</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="PLTR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.6390796" active="">(+4.64%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PLTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="5" data-tstyle="default" active=""><span class="txt-positive">+5.00</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PLTR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.6390796" data-tstyle="default" active=""><span class="txt-positive">+4.64%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="PLTR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="102566569" active="">102.567M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">111.583M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="PLTR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="253636575232" active="">253.637B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">593.58 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PLTR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="393.99915" data-tstyle="default" active=""><span class="txt-positive">+394.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Verona Pharma plc" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:VRNA" href="/quote/VRNA/" title="Verona Pharma plc" data-rapid_p="40"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">VRNA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Verona Pharma plc" class="leftAlignHeader yf-362rys enableMaxWidth">Verona Pharma plc</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:VRNA" href="/chart/VRNA" aria-label="Advanced Chart" data-rapid_p="41"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="VRNA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="VRNA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="65.46" active="">65.46</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="VRNA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.6800003" active="">+0.68</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="VRNA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.0497072" active="">(+1.05%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="VRNA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.6800003" data-tstyle="default" active=""><span class="txt-positive">+0.68</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="VRNA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.0497072" data-tstyle="default" active=""><span class="txt-positive">+1.05%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="VRNA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="766944" active="">766,944</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.385M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="VRNA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="8622652416" active="">8.623B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="VRNA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="320.69406" data-tstyle="default" active=""><span class="txt-positive">+320.69%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Federal National Mortgage Association" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:FNMA" href="/quote/FNMA/" title="Federal National Mortgage Association" data-rapid_p="42"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">FNMA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Federal National Mortgage Association" class="leftAlignHeader yf-362rys enableMaxWidth">Federal National Mortgage Association</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:FNMA" href="/chart/FNMA" aria-label="Advanced Chart" data-rapid_p="43"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="FNMA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="FNMA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="6.3" active="">6.30</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="FNMA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.07999992" active="">-0.08</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="FNMA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-1.2539172" active="">(-1.25%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FNMA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.07999992" data-tstyle="default" active=""><span class="txt-negative">-0.08</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FNMA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-1.2539172" data-tstyle="default" active=""><span class="txt-negative">-1.25%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FNMA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2065514" active="">2.066M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">10.068M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FNMA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="7377048064" active="">7.377B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FNMA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="311.7647" data-tstyle="default" active=""><span class="txt-positive">+311.76%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Kingsoft Cloud Holdings Limited" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:KC" href="/quote/KC/" title="Kingsoft Cloud Holdings Limited" data-rapid_p="44"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">KC </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Kingsoft Cloud Holdings Limited" class="leftAlignHeader yf-362rys enableMaxWidth">Kingsoft Cloud Holdings Limited</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:KC" href="/chart/KC" aria-label="Advanced Chart" data-rapid_p="45"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="KC chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="KC" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="11.96" active="">11.96</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="KC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.5799999" active="">-0.58</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="KC" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-4.625199" active="">(-4.63%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="KC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.5799999" data-tstyle="default" active=""><span class="txt-negative">-0.58</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="KC" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-4.625199" data-tstyle="default" active=""><span class="txt-negative">-4.63%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="KC" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1502429" active="">1.502M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">4.404M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="KC" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3316663296" active="">3.317B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="KC" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="279.68256" data-tstyle="default" active=""><span class="txt-positive">+279.68%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="AppLovin Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:APP" href="/quote/APP/" title="AppLovin Corporation" data-rapid_p="46"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">APP </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="AppLovin Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">AppLovin Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:APP" href="/chart/APP" aria-label="Advanced Chart" data-rapid_p="47"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="APP chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="APP" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="276.83" active="">276.83</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="APP" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.949982" active="">+8.95</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="APP" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="3.3410416" active="">(+3.34%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="APP" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.949982" data-tstyle="default" active=""><span class="txt-positive">+8.95</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="APP" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="3.3410416" data-tstyle="default" active=""><span class="txt-positive">+3.34%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="APP" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="5770373" active="">5.77M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">9.365M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="APP" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="90640506880" active="">90.641B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">60.98 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="APP" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="279.27112" data-tstyle="default" active=""><span class="txt-positive">+279.27%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Federal Home Loan Mortgage Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:FMCC" href="/quote/FMCC/" title="Federal Home Loan Mortgage Corporation" data-rapid_p="48"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">FMCC </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Federal Home Loan Mortgage Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Federal Home Loan Mortgage Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:FMCC" href="/chart/FMCC" aria-label="Advanced Chart" data-rapid_p="49"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="FMCC chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="FMCC" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="5.18" active="">5.18</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="FMCC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.10000038" active="">-0.10</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="FMCC" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-1.8939465" active="">(-1.89%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FMCC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.10000038" data-tstyle="default" active=""><span class="txt-negative">-0.10</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FMCC" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-1.8939465" data-tstyle="default" active=""><span class="txt-negative">-1.89%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FMCC" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="343761" active="">343,761</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.731M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FMCC" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3432314624" active="">3.432B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FMCC" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="262.23776" data-tstyle="default" active=""><span class="txt-positive">+262.24%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Alignment Healthcare, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ALHC" href="/quote/ALHC/" title="Alignment Healthcare, Inc." data-rapid_p="50"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ALHC </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Alignment Healthcare, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Alignment Healthcare, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ALHC" href="/chart/ALHC" aria-label="Advanced Chart" data-rapid_p="51"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ALHC chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ALHC" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="17.52" active="">17.52</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="ALHC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.52000046" active="">-0.52</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ALHC" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-2.8824859" active="">(-2.88%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ALHC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.52000046" data-tstyle="default" active=""><span class="txt-negative">-0.52</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ALHC" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-2.8824859" data-tstyle="default" active=""><span class="txt-negative">-2.88%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ALHC" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="3180916" active="">3.181M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.709M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ALHC" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3460655616" active="">3.461B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ALHC" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="244.8819" data-tstyle="default" active=""><span class="txt-positive">+244.88%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="ADMA Biologics, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ADMA" href="/quote/ADMA/" title="ADMA Biologics, Inc." data-rapid_p="52"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ADMA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="ADMA Biologics, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">ADMA Biologics, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ADMA" href="/chart/ADMA" aria-label="Advanced Chart" data-rapid_p="53"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ADMA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ADMA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="21.86" active="">21.86</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="ADMA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.4699993" active="">-0.47</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ADMA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-2.1047885" active="">(-2.10%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ADMA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.4699993" data-tstyle="default" active=""><span class="txt-negative">-0.47</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ADMA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-2.1047885" data-tstyle="default" active=""><span class="txt-negative">-2.10%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ADMA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2617355" active="">2.617M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.075M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ADMA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="5327129088" active="">5.327B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">26.99 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ADMA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="232.21884" data-tstyle="default" active=""><span class="txt-positive">+232.22%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="IonQ, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:IONQ" href="/quote/IONQ/" title="IonQ, Inc." data-rapid_p="54"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">IONQ </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="IonQ, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">IonQ, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:IONQ" href="/chart/IONQ" aria-label="Advanced Chart" data-rapid_p="55"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="IONQ chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="IONQ" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="28.9" active="">28.90</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="IONQ" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.51" active="">+0.51</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="IONQ" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.79641" active="">(+1.80%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="IONQ" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.51" data-tstyle="default" active=""><span class="txt-positive">+0.51</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="IONQ" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.79641" data-tstyle="default" active=""><span class="txt-positive">+1.80%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="IONQ" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="27575113" active="">27.575M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">19.069M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="IONQ" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="6903660544" active="">6.904B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="IONQ" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="223.99104" data-tstyle="default" active=""><span class="txt-positive">+223.99%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Brinker International, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:EAT" href="/quote/EAT/" title="Brinker International, Inc." data-rapid_p="56"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">EAT </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Brinker International, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Brinker International, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:EAT" href="/chart/EAT" aria-label="Advanced Chart" data-rapid_p="57"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="EAT chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="EAT" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="159.65" active="">159.65</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="EAT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="2.36" active="">+2.36</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="EAT" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.50041" active="">(+1.50%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EAT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="2.36" data-tstyle="default" active=""><span class="txt-positive">+2.36</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EAT" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.50041" data-tstyle="default" active=""><span class="txt-positive">+1.50%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EAT" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1331276" active="">1.331M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.568M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EAT" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="7089561088" active="">7.09B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">27.77 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EAT" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="221.48611" data-tstyle="default" active=""><span class="txt-positive">+221.49%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="LandBridge Company LLC" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:LB" href="/quote/LB/" title="LandBridge Company LLC" data-rapid_p="58"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">LB </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="LandBridge Company LLC" class="leftAlignHeader yf-362rys enableMaxWidth">LandBridge Company LLC</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:LB" href="/chart/LB" aria-label="Advanced Chart" data-rapid_p="59"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="LB chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="LB" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="72" active="">72.00</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="LB" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.18" active="">+0.18</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="LB" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.250627" active="">(+0.25%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LB" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.18" data-tstyle="default" active=""><span class="txt-positive">+0.18</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LB" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.250627" data-tstyle="default" active=""><span class="txt-positive">+0.25%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="LB" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="229828" active="">229,828</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">627,288 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="LB" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="5490540544" active="">5.491B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LB" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="211.01514" data-tstyle="default" active=""><span class="txt-positive">+211.02%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="TG Therapeutics, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:TGTX" href="/quote/TGTX/" title="TG Therapeutics, Inc." data-rapid_p="60"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">TGTX </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="TG Therapeutics, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">TG Therapeutics, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:TGTX" href="/chart/TGTX" aria-label="Advanced Chart" data-rapid_p="61"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="TGTX chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="TGTX" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="41.33" active="">41.33</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="TGTX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.0300026" active="">+1.03</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="TGTX" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="2.5558376" active="">(+2.56%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TGTX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.0300026" data-tstyle="default" active=""><span class="txt-positive">+1.03</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TGTX" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="2.5558376" data-tstyle="default" active=""><span class="txt-positive">+2.56%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TGTX" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1463330" active="">1.463M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.686M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TGTX" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="6491745280" active="">6.492B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">275.53 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TGTX" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="210.28528" data-tstyle="default" active=""><span class="txt-positive">+210.29%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Corcept Therapeutics Incorporated" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CORT" href="/quote/CORT/" title="Corcept Therapeutics Incorporated" data-rapid_p="62"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CORT </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Corcept Therapeutics Incorporated" class="leftAlignHeader yf-362rys enableMaxWidth">Corcept Therapeutics Incorporated</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CORT" href="/chart/CORT" aria-label="Advanced Chart" data-rapid_p="63"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CORT chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CORT" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="71.71" active="">71.71</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="CORT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.08000183" active="">-0.08</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CORT" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.111438684" active="">(-0.11%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CORT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.08000183" data-tstyle="default" active=""><span class="txt-negative">-0.08</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CORT" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.111438684" data-tstyle="default" active=""><span class="txt-negative">-0.11%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CORT" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1279549" active="">1.28M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.599M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CORT" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="7574082048" active="">7.574B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">58.30 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CORT" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="206.84637" data-tstyle="default" active=""><span class="txt-positive">+206.85%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Ubiquiti Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:UI" href="/quote/UI/" title="Ubiquiti Inc." data-rapid_p="64"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">UI </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Ubiquiti Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Ubiquiti Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:UI" href="/chart/UI" aria-label="Advanced Chart" data-rapid_p="65"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="UI chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="UI" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="313.09" active="">313.09</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="UI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.23999" active="">+0.24</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="UI" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.076711" active="">(+0.08%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="UI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.23999" data-tstyle="default" active=""><span class="txt-positive">+0.24</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="UI" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.076711" data-tstyle="default" active=""><span class="txt-positive">+0.08%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="UI" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="56051" active="">56,051</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">101,222 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="UI" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="18938908672" active="">18.939B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">42.54 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="UI" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="187.34398" data-tstyle="default" active=""><span class="txt-positive">+187.34%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Robinhood Markets, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:HOOD" href="/quote/HOOD/" title="Robinhood Markets, Inc." data-rapid_p="66"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">HOOD </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Robinhood Markets, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Robinhood Markets, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:HOOD" href="/chart/HOOD" aria-label="Advanced Chart" data-rapid_p="67"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="HOOD chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="HOOD" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="49.45" active="">49.45</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="HOOD" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.2999992" active="">+1.30</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="HOOD" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="2.6998944" active="">(+2.70%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="HOOD" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.2999992" data-tstyle="default" active=""><span class="txt-positive">+1.30</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="HOOD" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="2.6998944" data-tstyle="default" active=""><span class="txt-positive">+2.70%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="HOOD" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="34624078" active="">34.624M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">44.358M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="HOOD" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="42634948608" active="">42.635B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">31.70 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="HOOD" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="185.17879" data-tstyle="default" active=""><span class="txt-positive">+185.18%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Strategy Incorporated" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:MSTR" href="/quote/MSTR/" title="Strategy Incorporated" data-rapid_p="68"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">MSTR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Strategy Incorporated" class="leftAlignHeader yf-362rys enableMaxWidth">Strategy Incorporated</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:MSTR" href="/chart/MSTR" aria-label="Advanced Chart" data-rapid_p="69"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="MSTR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="MSTR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="368.71" active="">368.71</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="MSTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="18.369995" active="">+18.37</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="MSTR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.2434764" active="">(+5.24%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MSTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="18.369995" data-tstyle="default" active=""><span class="txt-positive">+18.37</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MSTR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.2434764" data-tstyle="default" active=""><span class="txt-positive">+5.24%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MSTR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="19338560" active="">19.339M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">18.181M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MSTR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="94203559936" active="">94.204B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MSTR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="185.16516" data-tstyle="default" active=""><span class="txt-positive">+185.17%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Carvana Co." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CVNA" href="/quote/CVNA/" title="Carvana Co." data-rapid_p="70"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CVNA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Carvana Co." class="leftAlignHeader yf-362rys enableMaxWidth">Carvana Co.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CVNA" href="/chart/CVNA" aria-label="Advanced Chart" data-rapid_p="71"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CVNA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CVNA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="237.15" active="">237.15</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="CVNA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="2.12999" active="">+2.13</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CVNA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.906301" active="">(+0.91%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CVNA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="2.12999" data-tstyle="default" active=""><span class="txt-positive">+2.13</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CVNA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.906301" data-tstyle="default" active=""><span class="txt-positive">+0.91%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CVNA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2944096" active="">2.944M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">4.836M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CVNA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="27733981184" active="">27.734B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">149.15 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CVNA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="183.13039" data-tstyle="default" active=""><span class="txt-positive">+183.13%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color:transparent; --hover-bg-color:transparent; --hover-color:var(--enabled-active-emph); --text-color:var(--enabled-active-emph); --hover-focus-color:var(--hovered-emph-same); --text-decoration:underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Xiaomi Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:XIACF" href="/quote/XIACF/" title="Xiaomi Corporation" data-rapid_p="72"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">XIACF </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Xiaomi Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Xiaomi Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:XIACF" href="/chart/XIACF" aria-label="Advanced Chart" data-rapid_p="73"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="XIACF chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="XIACF" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="6.2" active="">6.20</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="XIACF" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.13000011" active="">-0.13</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="XIACF" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-2.0537143" active="">(-2.05%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="XIACF" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.13000011" data-tstyle="default" active=""><span class="txt-negative">-0.13</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="XIACF" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-2.0537143" data-tstyle="default" active=""><span class="txt-negative">-2.05%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="XIACF" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="26900" active="">26,900</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">182,672 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="XIACF" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="160989200384" active="">160.989B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">47.69 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="XIACF" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="179.27928" data-tstyle="default" active=""><span class="txt-positive">+179.28%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> </tbody> <tfoot class="yf-269l37"><tr class="yf-269l37"> </tr></tfoot></table> </div> </div>'

# %%
_52_week_gainers_soup = bs4.BeautifulSoup(_52_week_gainers_html)

# %%
_52_week_gainers_tics = [tic.text.strip() for tic in _52_week_gainers_soup.find_all('span', class_="symbol yf-86iz4a")]
_52_week_gainers_tics
# Out:
# ['RLLVF',
#  'ASTS',
#  'WGS',
#  'SAFS',
#  'RGTI',
#  'SMMT',
#  'RKLB',
#  'PLTR',
#  'VRNA',
#  'FNMA',
#  'KC',
#  'APP',
#  'FMCC',
#  'ALHC',
#  'ADMA',
#  'IONQ',
#  'EAT',
#  'LB',
#  'TGTX',
#  'CORT',
#  'UI',
#  'HOOD',
#  'MSTR',
#  'CVNA',
#  'XIACF']

# %%
_52_week_losers_html = '<section class="yf-12mq010"><header class="large mb-0 yf-13lpgjv font-condensed"><h2 class="header yf-13lpgjv">Stocks</h2> </header>  <div class="container yf-j24h8w"><nav aria-label="stocks" class=" l1 yf-14syam2"><ul class="nav-list tw-p-0 tw-text-md yf-14syam2" role="menubar" aria-label="stocks menubar"><li role="none" class="yf-14syam2"><a href="/markets/stocks/most-active/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Most%20Active;milestonelink:" class="item yf-14syam2" title="Most Active" data-rapid_p="16" data-v9y="1"> <span class="ellipsis yf-14syam2">Most Active</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/trending/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Trending%20Now;milestonelink:" class="item yf-14syam2" title="Trending Now" data-rapid_p="17" data-v9y="1"> <span class="ellipsis yf-14syam2">Trending Now</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/gainers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Top%20Gainers;milestonelink:" class="item yf-14syam2" title="Top Gainers" data-rapid_p="18" data-v9y="1"> <span class="ellipsis yf-14syam2">Top Gainers</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/losers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Top%20Losers;milestonelink:" class="item yf-14syam2" title="Top Losers" data-rapid_p="19" data-v9y="1"> <span class="ellipsis yf-14syam2">Top Losers</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/52-week-gainers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:52%20Week%20Gainers;milestonelink:" class="item yf-14syam2" title="52 Week Gainers" data-rapid_p="20" data-v9y="1"> <span class="ellipsis yf-14syam2">52 Week Gainers</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/52-week-losers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:52%20Week%20Losers;milestonelink:" class="item yf-14syam2 selected" title="52 Week Losers" data-rapid_p="21" data-v9y="1" aria-current="page"> <span class="ellipsis yf-14syam2">52 Week Losers</span>   </a> </li></ul></nav> <div class="controls yf-j24h8w"><fieldset class="switch-group tertiary yf-1qaxug3"><div class="button-switch sz-x-small yf-1sf5ssy"><input type="checkbox" id="swc-crrny03s" data-ylk="subsec:52-week-losers;elm:tab;itc:1;sec:stocks-datatable;slk:Table%20View" class="yf-1sf5ssy" value="table" data-rapid_p="22" data-v9y="1"> <label for="swc-crrny03s" class="yf-1sf5ssy">table</label> Table View</div> <div class="button-switch sz-x-small yf-1sf5ssy"><input type="checkbox" id="swc-38ucq526" data-ylk="sec:stocks-heatmap;slk:Heatmap%20View;subsec:52-week-losers;elm:tab;itc:1" class="yf-1sf5ssy" value="heatmap" data-rapid_p="23" data-v9y="1"> <label for="swc-38ucq526" class="yf-1sf5ssy">heatmap</label> Heatmap View</div></fieldset> </div> <div class="tableContainer yf-j24h8w"><div class="table-container cs-regular tw-border-none yf-269l37"><table class="yf-269l37 bd"><thead class="yf-269l37"><tr class="yf-269l37"><th class="[&amp;_.symbol]:tw-text-md yf-269l37 so lpin shad"><div class="colCont yf-269l37"> Symbol</div></th><th class="leftAlignHeader yf-269l37 so"><div class="colCont yf-269l37"> Name</div></th><th class=" yf-269l37"><div class="colCont yf-269l37"> <span>&nbsp;</span></div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Price</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Change</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Change %</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Volume</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Avg Vol (3M)</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Market Cap</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> <div class="yf-10yevti"><span>P/E Ratio </span><span>(TTM) </span></div></div></th><th class="yf-269l37 so sorted"><div class="colCont yf-269l37"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-large yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="m12 8-6 6 1.41 1.41L12 10.83l4.59 4.58L18 14z"></path></svg></div> <div class="yf-10yevti"><span>52 Wk </span><span>Change % </span></div></div></th><th class=" yf-269l37"><div class="colCont yf-269l37"> 52 Wk Range</div></th> </tr></thead> <tbody><tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Atos SE" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:AEXAY" href="/quote/AEXAY/" title="Atos SE" data-rapid_p="279" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">AEXAY </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Atos SE" class="leftAlignHeader yf-362rys enableMaxWidth">Atos SE</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:AEXAY" href="/chart/AEXAY" aria-label="Advanced Chart" data-rapid_p="280" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="AEXAY chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="AEXAY" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="9" active="">9.00</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="AEXAY" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.999" active="">+9.00</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="AEXAY" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="899899.94" active="">(+899,899.90%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AEXAY" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.999" data-tstyle="default" active=""><span class="txt-positive">+9.00</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AEXAY" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="899899.94" data-tstyle="default" active=""><span class="txt-positive">+899,899.90%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AEXAY" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="742500" active="">742,500</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">354 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AEXAY" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="856613632" active="">856.614M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">0.13 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AEXAY" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-99.81754" data-tstyle="default" active=""><span class="txt-negative">-99.82%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Tonix Pharmaceuticals Holding Corp." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:TNXP" href="/quote/TNXP/" title="Tonix Pharmaceuticals Holding Corp." data-rapid_p="281" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">TNXP </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Tonix Pharmaceuticals Holding Corp." class="leftAlignHeader yf-362rys enableMaxWidth">Tonix Pharmaceuticals Holding Corp.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:TNXP" href="/chart/TNXP" aria-label="Advanced Chart" data-rapid_p="282" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="TNXP chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="TNXP" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="17.82" active="">17.82</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="TNXP" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.62999916" active="">+0.63</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="TNXP" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="3.6649163" active="">(+3.66%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TNXP" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.62999916" data-tstyle="default" active=""><span class="txt-positive">+0.63</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TNXP" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="3.6649163" data-tstyle="default" active=""><span class="txt-positive">+3.66%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TNXP" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="808850" active="">808,850</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.605M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TNXP" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="122562752" active="">122.563M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TNXP" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-96.90625" data-tstyle="default" active=""><span class="txt-negative">-96.91%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Hemogenyx Pharmaceuticals Plc" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:HOPHF" href="/quote/HOPHF/" title="Hemogenyx Pharmaceuticals Plc" data-rapid_p="283" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">HOPHF </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Hemogenyx Pharmaceuticals Plc" class="leftAlignHeader yf-362rys enableMaxWidth">Hemogenyx Pharmaceuticals Plc</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:HOPHF" href="/chart/HOPHF" aria-label="Advanced Chart" data-rapid_p="284" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="HOPHF chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="HOPHF" data-field="regularMarketPrice" data-trend="none" data-pricehint="4" data-value="1.24" active="">1.2400</fin-streamer> <div class="hide-desktop hide-mw "><fin-streamer data-test="colorChange" data-symbol="HOPHF" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0" active="">0.0000</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="HOPHF" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="4" data-value="0" active="">(0.00%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="HOPHF" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0" data-tstyle="default" active=""><span class="">0.0000</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="HOPHF" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0" data-tstyle="default" active=""><span class="">0.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="HOPHF" data-field="regularMarketVolume" data-trend="none" data-pricehint="4" data-value="25000" active="">25,000</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">0 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="HOPHF" data-field="marketCap" data-trend="none" data-pricehint="4" data-value="22929212" active="">22.929M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="HOPHF" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-92.25" data-tstyle="default" active=""><span class="txt-negative">-92.25%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="QXO, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:QXO" href="/quote/QXO/" title="QXO, Inc." data-rapid_p="285" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">QXO </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="QXO, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">QXO, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:QXO" href="/chart/QXO" aria-label="Advanced Chart" data-rapid_p="286" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="QXO chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="QXO" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="12.88" active="">12.88</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="QXO" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.13" active="">+0.13</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="QXO" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.01961" active="">(+1.02%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="QXO" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.13" data-tstyle="default" active=""><span class="txt-positive">+0.13</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="QXO" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.01961" data-tstyle="default" active=""><span class="txt-positive">+1.02%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="QXO" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="4976668" active="">4.977M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.491M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="QXO" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="5759498240" active="">5.759B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="QXO" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-89.26667" data-tstyle="default" active=""><span class="txt-negative">-89.27%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Coronado Global Resources Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CODQL" href="/quote/CODQL/" title="Coronado Global Resources Inc." data-rapid_p="287" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CODQL </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Coronado Global Resources Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Coronado Global Resources Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CODQL" href="/chart/CODQL" aria-label="Advanced Chart" data-rapid_p="288" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CODQL chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CODQL" data-field="regularMarketPrice" data-trend="none" data-pricehint="4" data-value="0.151" active="">0.1510</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="CODQL" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="-0.004000008" active="">-0.0040</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CODQL" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="4" data-value="-2.5806503" active="">(-2.58%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CODQL" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="-0.004000008" data-tstyle="default" active=""><span class="txt-negative">-0.0040</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CODQL" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-2.5806503" data-tstyle="default" active=""><span class="txt-negative">-2.58%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CODQL" data-field="regularMarketVolume" data-trend="none" data-pricehint="4" data-value="50000" active="">50,000</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">14,753 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CODQL" data-field="marketCap" data-trend="none" data-pricehint="4" data-value="2785949952" active="">2.786B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CODQL" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-79.86667" data-tstyle="default" active=""><span class="txt-negative">-79.87%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Moderna, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:MRNA" href="/quote/MRNA/" title="Moderna, Inc." data-rapid_p="289" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">MRNA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Moderna, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Moderna, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:MRNA" href="/chart/MRNA" aria-label="Advanced Chart" data-rapid_p="290" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="MRNA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="MRNA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="27.22" active="">27.22</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="MRNA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.17000008" active="">-0.17</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="MRNA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.6206648" active="">(-0.62%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MRNA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.17000008" data-tstyle="default" active=""><span class="txt-negative">-0.17</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MRNA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.6206648" data-tstyle="default" active=""><span class="txt-negative">-0.62%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MRNA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="7719074" active="">7.719M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">10.657M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MRNA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="10589586432" active="">10.59B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MRNA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-75.61369" data-tstyle="default" active=""><span class="txt-negative">-75.61%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Celanese Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CE" href="/quote/CE/" title="Celanese Corporation" data-rapid_p="291" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CE </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Celanese Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Celanese Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CE" href="/chart/CE" aria-label="Advanced Chart" data-rapid_p="292" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CE chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CE" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="43.53" active="">43.53</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="CE" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.18" active="">-0.18</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CE" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.411806" active="">(-0.41%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CE" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.18" data-tstyle="default" active=""><span class="txt-negative">-0.18</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CE" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.411806" data-tstyle="default" active=""><span class="txt-negative">-0.41%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CE" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2317587" active="">2.318M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.867M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CE" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="4884762112" active="">4.885B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CE" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-72.37945" data-tstyle="default" active=""><span class="txt-negative">-72.38%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Acadia Healthcare Company, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ACHC" href="/quote/ACHC/" title="Acadia Healthcare Company, Inc." data-rapid_p="293" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ACHC </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Acadia Healthcare Company, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Acadia Healthcare Company, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ACHC" href="/chart/ACHC" aria-label="Advanced Chart" data-rapid_p="294" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ACHC chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ACHC" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="22.15" active="">22.15</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="ACHC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.030000687" active="">-0.03</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ACHC" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.13526009" active="">(-0.14%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ACHC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.030000687" data-tstyle="default" active=""><span class="txt-negative">-0.03</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ACHC" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.13526009" data-tstyle="default" active=""><span class="txt-negative">-0.14%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ACHC" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1864268" active="">1.864M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.271M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ACHC" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2043395072" active="">2.043B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">7.97 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ACHC" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-70.312294" data-tstyle="default" active=""><span class="txt-negative">-70.31%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Weatherford International plc" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:WFRD" href="/quote/WFRD/" title="Weatherford International plc" data-rapid_p="295"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">WFRD </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Weatherford International plc" class="leftAlignHeader yf-362rys enableMaxWidth">Weatherford International plc</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:WFRD" href="/chart/WFRD" aria-label="Advanced Chart" data-rapid_p="296"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="WFRD chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="WFRD" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="42.74" active="">42.74</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="WFRD" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.300003" active="">+1.30</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="WFRD" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="3.137073" active="">(+3.14%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="WFRD" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.300003" data-tstyle="default" active=""><span class="txt-positive">+1.30</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="WFRD" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="3.137073" data-tstyle="default" active=""><span class="txt-positive">+3.14%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="WFRD" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2610513" active="">2.611M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.63M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="WFRD" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3101047552" active="">3.101B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">6.81 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="WFRD" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-66.932304" data-tstyle="default" active=""><span class="txt-negative">-66.93%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Viking Therapeutics, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:VKTX" href="/quote/VKTX/" title="Viking Therapeutics, Inc." data-rapid_p="297"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">VKTX </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Viking Therapeutics, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Viking Therapeutics, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:VKTX" href="/chart/VKTX" aria-label="Advanced Chart" data-rapid_p="298"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="VKTX chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="VKTX" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="24.99" active="">24.99</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="VKTX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.6700001" active="">-0.67</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="VKTX" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-2.611068" active="">(-2.61%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="VKTX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.6700001" data-tstyle="default" active=""><span class="txt-negative">-0.67</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="VKTX" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-2.611068" data-tstyle="default" active=""><span class="txt-negative">-2.61%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="VKTX" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="3960974" active="">3.961M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">4.672M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="VKTX" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2881321984" active="">2.881B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="VKTX" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-66.865555" data-tstyle="default" active=""><span class="txt-negative">-66.87%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Atkore Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ATKR" href="/quote/ATKR/" title="Atkore Inc." data-rapid_p="299"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ATKR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Atkore Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Atkore Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ATKR" href="/chart/ATKR" aria-label="Advanced Chart" data-rapid_p="300"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ATKR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ATKR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="63.93" active="">63.93</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="ATKR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.57" active="">-0.57</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ATKR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.88372" active="">(-0.88%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ATKR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.57" data-tstyle="default" active=""><span class="txt-negative">-0.57</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ATKR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.88372" data-tstyle="default" active=""><span class="txt-negative">-0.88%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ATKR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="275125" active="">275,125</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">753,031 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ATKR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2218716160" active="">2.219B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">6.15 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ATKR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-65.09609" data-tstyle="default" active=""><span class="txt-negative">-65.10%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="e.l.f. Beauty, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ELF" href="/quote/ELF/" title="e.l.f. Beauty, Inc." data-rapid_p="301"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ELF </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="e.l.f. Beauty, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">e.l.f. Beauty, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ELF" href="/chart/ELF" aria-label="Advanced Chart" data-rapid_p="302"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ELF chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ELF" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="61.15" active="">61.15</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="ELF" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.490002" active="">+0.49</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ELF" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.807784" active="">(+0.81%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ELF" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.490002" data-tstyle="default" active=""><span class="txt-positive">+0.49</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ELF" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.807784" data-tstyle="default" active=""><span class="txt-positive">+0.81%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ELF" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2207762" active="">2.208M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.305M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ELF" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3448774400" active="">3.449B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">36.62 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ELF" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-64.41871" data-tstyle="default" active=""><span class="txt-negative">-64.42%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Apellis Pharmaceuticals, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:APLS" href="/quote/APLS/" title="Apellis Pharmaceuticals, Inc." data-rapid_p="303"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">APLS </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Apellis Pharmaceuticals, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Apellis Pharmaceuticals, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:APLS" href="/chart/APLS" aria-label="Advanced Chart" data-rapid_p="304"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="APLS chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="APLS" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="17.49" active="">17.49</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="APLS" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.050001144" active="">-0.05</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="APLS" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.28506923" active="">(-0.29%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="APLS" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.050001144" data-tstyle="default" active=""><span class="txt-negative">-0.05</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="APLS" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-0.28506923" data-tstyle="default" active=""><span class="txt-negative">-0.29%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="APLS" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2870339" active="">2.87M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.01M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="APLS" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2204474624" active="">2.204B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="APLS" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-63.44063" data-tstyle="default" active=""><span class="txt-negative">-63.44%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Stellantis N.V." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:STLA" href="/quote/STLA/" title="Stellantis N.V." data-rapid_p="305"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">STLA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Stellantis N.V." class="leftAlignHeader yf-362rys enableMaxWidth">Stellantis N.V.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:STLA" href="/chart/STLA" aria-label="Advanced Chart" data-rapid_p="306"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="STLA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="STLA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="9.42" active="">9.42</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="STLA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.0900002" active="">+0.09</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="STLA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.964632" active="">(+0.96%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="STLA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.0900002" data-tstyle="default" active=""><span class="txt-positive">+0.09</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="STLA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.964632" data-tstyle="default" active=""><span class="txt-positive">+0.96%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="STLA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="6111795" active="">6.112M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">19.183M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="STLA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="27134310400" active="">27.134B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">4.53 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="STLA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-62.19904" data-tstyle="default" active=""><span class="txt-negative">-62.20%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Xinyi Solar Holdings Limited" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:XNYIF" href="/quote/XNYIF/" title="Xinyi Solar Holdings Limited" data-rapid_p="307"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">XNYIF </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Xinyi Solar Holdings Limited" class="leftAlignHeader yf-362rys enableMaxWidth">Xinyi Solar Holdings Limited</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:XNYIF" href="/chart/XNYIF" aria-label="Advanced Chart" data-rapid_p="308"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="XNYIF chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="XNYIF" data-field="regularMarketPrice" data-trend="none" data-pricehint="4" data-value="0.2722" active="">0.2722</fin-streamer> <div class="hide-desktop hide-mw "><fin-streamer data-test="colorChange" data-symbol="XNYIF" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0" active="">0.0000</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="XNYIF" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="4" data-value="0" active="">(0.00%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="XNYIF" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0" data-tstyle="default" active=""><span class="">0.0000</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="XNYIF" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0" data-tstyle="default" active=""><span class="">0.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="XNYIF" data-field="regularMarketVolume" data-trend="none" data-pricehint="4" data-value="30000" active="">30,000</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1,159 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="XNYIF" data-field="marketCap" data-trend="none" data-pricehint="4" data-value="3018534400" active="">3.019B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">27.22 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="XNYIF" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-61.7132" data-tstyle="default" active=""><span class="txt-negative">-61.71%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Civitas Resources, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CIVI" href="/quote/CIVI/" title="Civitas Resources, Inc." data-rapid_p="309"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CIVI </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Civitas Resources, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Civitas Resources, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CIVI" href="/chart/CIVI" aria-label="Advanced Chart" data-rapid_p="310"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CIVI chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CIVI" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="29.48" active="">29.48</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="CIVI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.0499992" active="">+0.05</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CIVI" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.169892" active="">(+0.17%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CIVI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.0499992" data-tstyle="default" active=""><span class="txt-positive">+0.05</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CIVI" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.169892" data-tstyle="default" active=""><span class="txt-positive">+0.17%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CIVI" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1124844" active="">1.125M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.304M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CIVI" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2729063680" active="">2.729B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.48 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CIVI" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-60.519623" data-tstyle="default" active=""><span class="txt-negative">-60.52%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Transocean Ltd." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:RIG" href="/quote/RIG/" title="Transocean Ltd." data-rapid_p="311"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">RIG </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Transocean Ltd." class="leftAlignHeader yf-362rys enableMaxWidth">Transocean Ltd.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:RIG" href="/chart/RIG" aria-label="Advanced Chart" data-rapid_p="312"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="RIG chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="RIG" data-field="regularMarketPrice" data-trend="none" data-pricehint="4" data-value="2.33" active="">2.3300</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="RIG" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0.04" active="">+0.0400</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="RIG" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="4" data-value="1.74672" active="">(+1.75%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RIG" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="0.04" data-tstyle="default" active=""><span class="txt-positive">+0.0400</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RIG" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.74672" data-tstyle="default" active=""><span class="txt-positive">+1.75%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RIG" data-field="regularMarketVolume" data-trend="none" data-pricehint="4" data-value="24197397" active="">24.197M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">38.881M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RIG" data-field="marketCap" data-trend="none" data-pricehint="4" data-value="2057998080" active="">2.058B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RIG" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-59.965633" data-tstyle="default" active=""><span class="txt-negative">-59.97%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="The Estée Lauder Companies Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:EL" href="/quote/EL/" title="The Estée Lauder Companies Inc." data-rapid_p="313"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">EL </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="The Estée Lauder Companies Inc." class="leftAlignHeader yf-362rys enableMaxWidth">The Estée Lauder Companies Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:EL" href="/chart/EL" aria-label="Advanced Chart" data-rapid_p="314"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="EL chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="EL" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="59.39" active="">59.39</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="EL" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.739998" active="">+0.74</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="EL" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.26172" active="">(+1.26%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EL" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.739998" data-tstyle="default" active=""><span class="txt-positive">+0.74</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EL" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.26172" data-tstyle="default" active=""><span class="txt-positive">+1.26%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EL" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2146148" active="">2.146M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">4.546M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EL" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="21097287680" active="">21.097B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EL" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-59.540844" data-tstyle="default" active=""><span class="txt-negative">-59.54%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Super Micro Computer, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SMCI" href="/quote/SMCI/" title="Super Micro Computer, Inc." data-rapid_p="315"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SMCI </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Super Micro Computer, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Super Micro Computer, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SMCI" href="/chart/SMCI" aria-label="Advanced Chart" data-rapid_p="316"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SMCI chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SMCI" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="36.47" active="">36.47</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="SMCI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.65999985" active="">+0.66</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SMCI" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.8430601" active="">(+1.84%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SMCI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.65999985" data-tstyle="default" active=""><span class="txt-positive">+0.66</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SMCI" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="1.8430601" data-tstyle="default" active=""><span class="txt-positive">+1.84%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SMCI" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="38163413" active="">38.163M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">76.163M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SMCI" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="21644253184" active="">21.644B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">15.86 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SMCI" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-59.038578" data-tstyle="default" active=""><span class="txt-negative">-59.04%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Olin Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:OLN" href="/quote/OLN/" title="Olin Corporation" data-rapid_p="317"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">OLN </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Olin Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Olin Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:OLN" href="/chart/OLN" aria-label="Advanced Chart" data-rapid_p="318"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="OLN chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="OLN" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="22" active="">22.00</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="OLN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.23" active="">-0.23</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="OLN" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-1.03464" active="">(-1.03%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="OLN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.23" data-tstyle="default" active=""><span class="txt-negative">-0.23</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="OLN" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-1.03464" data-tstyle="default" active=""><span class="txt-negative">-1.03%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="OLN" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1098243" active="">1.098M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.063M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="OLN" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2558291968" active="">2.558B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">24.18 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="OLN" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-58.909225" data-tstyle="default" active=""><span class="txt-negative">-58.91%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Enphase Energy, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ENPH" href="/quote/ENPH/" title="Enphase Energy, Inc." data-rapid_p="319"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ENPH </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Enphase Energy, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Enphase Energy, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ENPH" href="/chart/ENPH" aria-label="Advanced Chart" data-rapid_p="320"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ENPH chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ENPH" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="46.83" active="">46.83</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="ENPH" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.0800018" active="">+1.08</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ENPH" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="2.3606596" active="">(+2.36%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ENPH" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.0800018" data-tstyle="default" active=""><span class="txt-positive">+1.08</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ENPH" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="2.3606596" data-tstyle="default" active=""><span class="txt-positive">+2.36%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ENPH" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="4641281" active="">4.641M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">4.639M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ENPH" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="6144423936" active="">6.144B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">42.96 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ENPH" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-58.86693" data-tstyle="default" active=""><span class="txt-negative">-58.87%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Coty Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:COTY" href="/quote/COTY/" title="Coty Inc." data-rapid_p="321"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">COTY </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Coty Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Coty Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:COTY" href="/chart/COTY" aria-label="Advanced Chart" data-rapid_p="322"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="COTY chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="COTY" data-field="regularMarketPrice" data-trend="none" data-pricehint="4" data-value="4.97" active="">4.9700</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="COTY" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="-0.0700002" active="">-0.0700</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="COTY" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="4" data-value="-1.38889" active="">(-1.39%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="COTY" data-field="regularMarketChange" data-trend="txt" data-pricehint="4" data-value="-0.0700002" data-tstyle="default" active=""><span class="txt-negative">-0.0700</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="COTY" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-1.38889" data-tstyle="default" active=""><span class="txt-negative">-1.39%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="COTY" data-field="regularMarketVolume" data-trend="none" data-pricehint="4" data-value="5509408" active="">5.509M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">7.853M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="COTY" data-field="marketCap" data-trend="none" data-pricehint="4" data-value="4394846720" active="">4.395B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="COTY" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-56.85764" data-tstyle="default" active=""><span class="txt-negative">-56.86%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="DoubleVerify Holdings, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:DV" href="/quote/DV/" title="DoubleVerify Holdings, Inc." data-rapid_p="323"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">DV </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="DoubleVerify Holdings, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">DoubleVerify Holdings, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:DV" href="/chart/DV" aria-label="Advanced Chart" data-rapid_p="324"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="DV chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="DV" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="13.28" active="">13.28</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="DV" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.11" active="">+0.11</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="DV" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.835229" active="">(+0.84%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="DV" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.11" data-tstyle="default" active=""><span class="txt-positive">+0.11</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="DV" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0.835229" data-tstyle="default" active=""><span class="txt-positive">+0.84%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="DV" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1267371" active="">1.267M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.503M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="DV" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2157707776" active="">2.158B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">41.50 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="DV" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-56.60131" data-tstyle="default" active=""><span class="txt-negative">-56.60%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Cleveland-Cliffs Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CLF" href="/quote/CLF/" title="Cleveland-Cliffs Inc." data-rapid_p="325"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CLF </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Cleveland-Cliffs Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Cleveland-Cliffs Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CLF" href="/chart/CLF" aria-label="Advanced Chart" data-rapid_p="326"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CLF chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CLF" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="7.91" active="">7.91</fin-streamer> <div class="hide-desktop hide-mw "><fin-streamer data-test="colorChange" data-symbol="CLF" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0" active="">0.00</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CLF" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0" active="">(0.00%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CLF" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0" data-tstyle="default" active=""><span class="">0.00</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CLF" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0" data-tstyle="default" active=""><span class="">0.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CLF" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="11952645" active="">11.953M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">21.713M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CLF" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3911376128" active="">3.911B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CLF" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-56.201553" data-tstyle="default" active=""><span class="txt-negative">-56.20%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Forge Global Holdings, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:FRGE" href="/quote/FRGE/" title="Forge Global Holdings, Inc." data-rapid_p="327"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">FRGE </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Forge Global Holdings, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Forge Global Holdings, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:FRGE" href="/chart/FRGE" aria-label="Advanced Chart" data-rapid_p="328"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="FRGE chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="FRGE" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="12.71" active="">12.71</fin-streamer> <div class="hide-desktop hide-mw "><fin-streamer data-test="colorChange" data-symbol="FRGE" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0" active="">0.00</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="FRGE" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0" active="">(0.00%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FRGE" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0" data-tstyle="default" active=""><span class="">0.00</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FRGE" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="0" data-tstyle="default" active=""><span class="">0.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FRGE" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="142432" active="">142,432</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">95,315 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FRGE" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="159420256" active="">159.42M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FRGE" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-55.403507" data-tstyle="default" active=""><span class="txt-negative">-55.40%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> </tbody> <tfoot class="yf-269l37"><tr class="yf-269l37"> </tr></tfoot></table> </div> </div> <div class="paginationContainer yf-1tdhqb1"><div class="select-dropdown yf-1tdhqb1">Rows per page <div class="container  yf-3h01le"><div style="display: contents; --menu-max-height: var(--select-max-height, 300px);"><div class="menuContainer  yf-33jgs4" style="                    "><button class="tertiary-btn fin-size-small menuBtn rounded rightAlign yf-9i625" data-ylk="elmt:menu;itc:1;elm:inpt;sec:stocks-select;subsec:52-week-losers" aria-haspopup="listbox" aria-controls="menu-93" aria-label="25" type="button" title="25" data-rapid_p="329"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z"></path></svg></div> <span class=" textSelect yf-3h01le">25</span> </button> <div class="dialog-container yf-33jgs4" id="menu-93" aria-hidden="true"></div></div></div></div></div> <div class="total yf-1tdhqb1">1-25 of 900</div> <div class="buttons yf-1tdhqb1"><button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:52-week-losers;elm:arrow;itc:1;slk:first-pg" data-testid="first-page-button" disabled="" aria-label="Goto first page" data-rapid_p="330"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M18.41 16.59 13.82 12l4.59-4.59L17 6l-6 6 6 6zM6 6h2v12H6z"></path></svg></div> </button> <button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:52-week-losers;elm:arrow;itc:1;slk:prev" data-testid="prev-page-button" disabled="" aria-label="Goto previous page" data-rapid_p="331"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M15.41 16.59 10.83 12l4.58-4.59L14 6l-6 6 6 6z"></path></svg></div> </button> <button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:52-week-losers;elm:arrow;itc:1;slk:next" data-testid="next-page-button" aria-label="Goto next page" data-rapid_p="332"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M8.59 16.59 13.17 12 8.59 7.41 10 6l6 6-6 6z"></path></svg></div> </button> <button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:52-week-losers;elm:arrow;itc:1;slk:last-pg" data-testid="last-page-button" aria-label="Goto last page" data-rapid_p="333"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M5.59 7.41 10.18 12l-4.59 4.59L7 18l6-6-6-6zM16 6h2v12h-2z"></path></svg></div> </button></div></div></div> </section>'

# %%
_52_week_losers_soup = bs4.BeautifulSoup(_52_week_losers_html)

# %%
_52_week_losers_tics = [tic.text.strip() for tic in _52_week_losers_soup.find_all('span', class_="symbol yf-86iz4a")]
_52_week_losers_tics
# Out:
# ['AEXAY',
#  'TNXP',
#  'HOPHF',
#  'QXO',
#  'CODQL',
#  'MRNA',
#  'CE',
#  'ACHC',
#  'WFRD',
#  'VKTX',
#  'ATKR',
#  'ELF',
#  'APLS',
#  'STLA',
#  'XNYIF',
#  'CIVI',
#  'RIG',
#  'EL',
#  'SMCI',
#  'OLN',
#  'ENPH',
#  'COTY',
#  'DV',
#  'CLF',
#  'FRGE']

# %%
top_gainers_html = '<section class="yf-12mq010"><header class="large mb-0 yf-13lpgjv font-condensed"><h2 class="header yf-13lpgjv">Stocks</h2> </header>  <div class="container yf-j24h8w"><nav aria-label="stocks" class=" l1 yf-14syam2"><ul class="nav-list tw-p-0 tw-text-md yf-14syam2" role="menubar" aria-label="stocks menubar"><li role="none" class="yf-14syam2"><a href="/markets/stocks/most-active/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Most%20Active;milestonelink:" class="item yf-14syam2" title="Most Active" data-rapid_p="16" data-v9y="1"> <span class="ellipsis yf-14syam2">Most Active</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/trending/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Trending%20Now;milestonelink:" class="item yf-14syam2" title="Trending Now" data-rapid_p="17" data-v9y="1"> <span class="ellipsis yf-14syam2">Trending Now</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/gainers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Top%20Gainers;milestonelink:" class="item yf-14syam2 selected" title="Top Gainers" data-rapid_p="18" data-v9y="1" aria-current="page"> <span class="ellipsis yf-14syam2">Top Gainers</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/losers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Top%20Losers;milestonelink:" class="item yf-14syam2" title="Top Losers" data-rapid_p="19" data-v9y="1"> <span class="ellipsis yf-14syam2">Top Losers</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/52-week-gainers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:52%20Week%20Gainers;milestonelink:" class="item yf-14syam2" title="52 Week Gainers" data-rapid_p="20" data-v9y="1"> <span class="ellipsis yf-14syam2">52 Week Gainers</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/52-week-losers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:52%20Week%20Losers;milestonelink:" class="item yf-14syam2" title="52 Week Losers" data-rapid_p="21" data-v9y="1"> <span class="ellipsis yf-14syam2">52 Week Losers</span>   </a> </li></ul></nav> <div class="controls yf-j24h8w"><fieldset class="switch-group tertiary yf-1qaxug3"><div class="button-switch sz-x-small yf-1sf5ssy"><input type="checkbox" id="swc-crrny03s" data-ylk="subsec:gainers;elm:tab;itc:1;sec:stocks-datatable;slk:Table%20View" class="yf-1sf5ssy" value="table" data-rapid_p="22" data-v9y="1"> <label for="swc-crrny03s" class="yf-1sf5ssy">table</label> Table View</div> <div class="button-switch sz-x-small yf-1sf5ssy"><input type="checkbox" id="swc-38ucq526" data-ylk="sec:stocks-heatmap;slk:Heatmap%20View;subsec:gainers;elm:tab;itc:1" class="yf-1sf5ssy" value="heatmap" data-rapid_p="23" data-v9y="1"> <label for="swc-38ucq526" class="yf-1sf5ssy">heatmap</label> Heatmap View</div></fieldset> </div> <div class="tableContainer yf-j24h8w"><div class="table-container cs-regular tw-border-none yf-269l37"><table class="yf-269l37 bd"><thead class="yf-269l37"><tr class="yf-269l37"><th class="[&amp;_.symbol]:tw-text-md yf-269l37 so lpin shad"><div class="colCont yf-269l37"> Symbol</div></th><th class="leftAlignHeader yf-269l37 so"><div class="colCont yf-269l37"> Name</div></th><th class=" yf-269l37"><div class="colCont yf-269l37"> <span>&nbsp;</span></div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Price</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Change</div></th><th class="yf-269l37 so sorted"><div class="colCont yf-269l37"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z"></path></svg></div> Change %</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Volume</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Avg Vol (3M)</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Market Cap</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> <div class="yf-10yevti"><span>P/E Ratio </span><span>(TTM) </span></div></div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> <div class="yf-10yevti"><span>52 Wk </span><span>Change % </span></div></div></th><th class=" yf-269l37"><div class="colCont yf-269l37"> 52 Wk Range</div></th> </tr></thead> <tbody><tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Atos SE" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:AEXAY" href="/quote/AEXAY/" title="Atos SE" data-rapid_p="417" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">AEXAY </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Atos SE" class="leftAlignHeader yf-362rys enableMaxWidth">Atos SE</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:AEXAY" href="/chart/AEXAY" aria-label="Advanced Chart" data-rapid_p="418" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="AEXAY chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="AEXAY" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="9" active="">9.00</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="AEXAY" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.999" active="">+9.00</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="AEXAY" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="899899.94" active="">(+899,899.90%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AEXAY" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.999" data-tstyle="default" active=""><span class="txt-positive">+9.00</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AEXAY" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="899899.94" data-tstyle="default" active=""><span class="txt-positive">+899,899.90%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AEXAY" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="742500" active="">742,500</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">354 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AEXAY" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="856613632" active="">856.614M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">0.13 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AEXAY" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-99.81754" data-tstyle="default" active=""><span class="txt-negative">-99.82%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Sensient Technologies Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SXT" href="/quote/SXT/" title="Sensient Technologies Corporation" data-rapid_p="419" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SXT </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Sensient Technologies Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Sensient Technologies Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SXT" href="/chart/SXT" aria-label="Advanced Chart" data-rapid_p="420" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SXT chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SXT" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="90.99" active="">90.99</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="SXT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="10.85" active="">+10.85</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SXT" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="13.5388" active="">(+13.54%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SXT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="10.85" data-tstyle="default" active=""><span class="txt-positive">+10.85</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SXT" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="13.5388" data-tstyle="default" active=""><span class="txt-positive">+13.54%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SXT" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1458609" active="">1.459M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">337,275 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SXT" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3861397248" active="">3.861B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">30.95 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SXT" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="25.19263" data-tstyle="default" active=""><span class="txt-positive">+25.19%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Encompass Health Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:EHC" href="/quote/EHC/" title="Encompass Health Corporation" data-rapid_p="421" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">EHC </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Encompass Health Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Encompass Health Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:EHC" href="/chart/EHC" aria-label="Advanced Chart" data-rapid_p="422" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="EHC chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="EHC" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="113.37" active="">113.37</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="EHC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="11.96" active="">+11.96</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="EHC" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="11.7937" active="">(+11.79%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EHC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="11.96" data-tstyle="default" active=""><span class="txt-positive">+11.96</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EHC" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="11.7937" data-tstyle="default" active=""><span class="txt-positive">+11.79%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EHC" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2076447" active="">2.076M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">854,181 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EHC" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="11417379840" active="">11.417B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">23.33 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EHC" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="35.545193" data-tstyle="default" active=""><span class="txt-positive">+35.55%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Liberty Broadband Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:LBRDK" href="/quote/LBRDK/" title="Liberty Broadband Corporation" data-rapid_p="423" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">LBRDK </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Liberty Broadband Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Liberty Broadband Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:LBRDK" href="/chart/LBRDK" aria-label="Advanced Chart" data-rapid_p="424" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="LBRDK chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="LBRDK" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="86.23" active="">86.23</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="LBRDK" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.870003" active="">+8.87</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="LBRDK" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="11.465878" active="">(+11.47%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LBRDK" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.870003" data-tstyle="default" active=""><span class="txt-positive">+8.87</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LBRDK" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="11.465878" data-tstyle="default" active=""><span class="txt-positive">+11.47%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="LBRDK" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1177687" active="">1.178M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">851,972 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="LBRDK" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="11061670912" active="">11.062B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">14.18 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LBRDK" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="71.19317" data-tstyle="default" active=""><span class="txt-positive">+71.19%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Charter Communications, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CHTR" href="/quote/CHTR/" title="Charter Communications, Inc." data-rapid_p="425" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CHTR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Charter Communications, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Charter Communications, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CHTR" href="/chart/CHTR" aria-label="Advanced Chart" data-rapid_p="426" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CHTR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CHTR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="373.65" active="">373.65</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="CHTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="38.320007" active="">+38.32</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CHTR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="11.427551" active="">(+11.43%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CHTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="38.320007" data-tstyle="default" active=""><span class="txt-positive">+38.32</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CHTR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="11.427551" data-tstyle="default" active=""><span class="txt-positive">+11.43%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CHTR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2702319" active="">2.702M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.349M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CHTR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="53063528448" active="">53.064B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">10.68 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CHTR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="43.84432" data-tstyle="default" active=""><span class="txt-positive">+43.84%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Liberty Broadband Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:LBRDA" href="/quote/LBRDA/" title="Liberty Broadband Corporation" data-rapid_p="427" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">LBRDA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Liberty Broadband Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Liberty Broadband Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:LBRDA" href="/chart/LBRDA" aria-label="Advanced Chart" data-rapid_p="428" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="LBRDA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="LBRDA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="85.06" active="">85.06</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="LBRDA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.559998" active="">+8.56</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="LBRDA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="11.189539" active="">(+11.19%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LBRDA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="8.559998" data-tstyle="default" active=""><span class="txt-positive">+8.56</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LBRDA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="11.189539" data-tstyle="default" active=""><span class="txt-positive">+11.19%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="LBRDA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="459732" active="">459,732</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">123,842 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="LBRDA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="11061626880" active="">11.062B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">13.99 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LBRDA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="68.136" data-tstyle="default" active=""><span class="txt-positive">+68.14%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Core Scientific, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CORZ" href="/quote/CORZ/" title="Core Scientific, Inc." data-rapid_p="429" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CORZ </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Core Scientific, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Core Scientific, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CORZ" href="/chart/CORZ" aria-label="Advanced Chart" data-rapid_p="430" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CORZ chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CORZ" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="8.31" active="">8.31</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="CORZ" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.7800002" active="">+0.78</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CORZ" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="10.358568" active="">(+10.36%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CORZ" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.7800002" data-tstyle="default" active=""><span class="txt-positive">+0.78</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CORZ" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="10.358568" data-tstyle="default" active=""><span class="txt-positive">+10.36%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CORZ" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="13736507" active="">13.737M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">16.523M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CORZ" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2450544384" active="">2.451B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CORZ" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="162.14511" data-tstyle="default" active=""><span class="txt-positive">+162.15%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Tesla, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:TSLA" href="/quote/TSLA/" title="Tesla, Inc." data-rapid_p="431" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">TSLA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Tesla, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Tesla, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:TSLA" href="/chart/TSLA" aria-label="Advanced Chart" data-rapid_p="432" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="TSLA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="TSLA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="284.95" active="">284.95</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="TSLA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="25.440002" active="">+25.44</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="TSLA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="9.803091" active="">(+9.80%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TSLA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="25.440002" data-tstyle="default" active=""><span class="txt-positive">+25.44</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TSLA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="9.803091" data-tstyle="default" active=""><span class="txt-positive">+9.80%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TSLA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="167560688" active="">167.561M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">116.697M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TSLA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="917812609024" active="">917.813B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">163.76 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TSLA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="46.8436" data-tstyle="default" active=""><span class="txt-positive">+46.84%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="VeriSign, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:VRSN" href="/quote/VRSN/" title="VeriSign, Inc." data-rapid_p="433"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">VRSN </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="VeriSign, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">VeriSign, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:VRSN" href="/chart/VRSN" aria-label="Advanced Chart" data-rapid_p="434"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="VRSN chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="VRSN" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="272.79" active="">272.79</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="VRSN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="20.200012" active="">+20.20</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="VRSN" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="7.997154" active="">(+8.00%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="VRSN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="20.200012" data-tstyle="default" active=""><span class="txt-positive">+20.20</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="VRSN" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="7.997154" data-tstyle="default" active=""><span class="txt-positive">+8.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="VRSN" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1387177" active="">1.387M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">896,316 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="VRSN" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="25614981120" active="">25.615B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">33.35 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="VRSN" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="55.78208" data-tstyle="default" active=""><span class="txt-positive">+55.78%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Goosehead Insurance, Inc" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:GSHD" href="/quote/GSHD/" title="Goosehead Insurance, Inc" data-rapid_p="435"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">GSHD </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Goosehead Insurance, Inc" class="leftAlignHeader yf-362rys enableMaxWidth">Goosehead Insurance, Inc</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:GSHD" href="/chart/GSHD" aria-label="Advanced Chart" data-rapid_p="436"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="GSHD chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="GSHD" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="99.54" active="">99.54</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="GSHD" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="6.3499985" active="">+6.35</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="GSHD" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="6.8140345" active="">(+6.81%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="GSHD" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="6.3499985" data-tstyle="default" active=""><span class="txt-positive">+6.35</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="GSHD" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="6.8140345" data-tstyle="default" active=""><span class="txt-positive">+6.81%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="GSHD" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="992579" active="">992,579</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">293,060 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="GSHD" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3497696256" active="">3.498B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">82.95 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="GSHD" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="75.092354" data-tstyle="default" active=""><span class="txt-positive">+75.09%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Shin-Etsu Chemical Co., Ltd." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SHECY" href="/quote/SHECY/" title="Shin-Etsu Chemical Co., Ltd." data-rapid_p="437"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SHECY </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Shin-Etsu Chemical Co., Ltd." class="leftAlignHeader yf-362rys enableMaxWidth">Shin-Etsu Chemical Co., Ltd.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SHECY" href="/chart/SHECY" aria-label="Advanced Chart" data-rapid_p="438"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SHECY chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SHECY" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="14.84" active="">14.84</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="SHECY" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.9300003" active="">+0.93</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SHECY" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="6.6858397" active="">(+6.69%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SHECY" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.9300003" data-tstyle="default" active=""><span class="txt-positive">+0.93</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SHECY" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="6.6858397" data-tstyle="default" active=""><span class="txt-positive">+6.69%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SHECY" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="49299" active="">49,299</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">649,068 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SHECY" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="58170130432" active="">58.17B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">15.79 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SHECY" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-21.605915" data-tstyle="default" active=""><span class="txt-negative">-21.61%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="PENN Entertainment, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:PENN" href="/quote/PENN/" title="PENN Entertainment, Inc." data-rapid_p="439"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">PENN </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="PENN Entertainment, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">PENN Entertainment, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:PENN" href="/chart/PENN" aria-label="Advanced Chart" data-rapid_p="440"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="PENN chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="PENN" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="16.15" active="">16.15</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="PENN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1" active="">+1.00</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="PENN" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="6.6006603" active="">(+6.60%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PENN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1" data-tstyle="default" active=""><span class="txt-positive">+1.00</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PENN" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="6.6006603" data-tstyle="default" active=""><span class="txt-positive">+6.60%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="PENN" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="5616866" active="">5.617M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">4.213M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="PENN" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2463940864" active="">2.464B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PENN" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-5.167353" data-tstyle="default" active=""><span class="txt-negative">-5.17%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Comfort Systems USA, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:FIX" href="/quote/FIX/" title="Comfort Systems USA, Inc." data-rapid_p="441"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">FIX </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Comfort Systems USA, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Comfort Systems USA, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:FIX" href="/chart/FIX" aria-label="Advanced Chart" data-rapid_p="442"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="FIX chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="FIX" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="397.43" active="">397.43</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="FIX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="21.22" active="">+21.22</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="FIX" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.64047" active="">(+5.64%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FIX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="21.22" data-tstyle="default" active=""><span class="txt-positive">+21.22</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FIX" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.64047" data-tstyle="default" active=""><span class="txt-positive">+5.64%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FIX" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1314188" active="">1.314M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">579,044 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FIX" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="14019263488" active="">14.019B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">23.87 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FIX" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="27.918507" data-tstyle="default" active=""><span class="txt-positive">+27.92%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Loar Holdings Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:LOAR" href="/quote/LOAR/" title="Loar Holdings Inc." data-rapid_p="443"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">LOAR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Loar Holdings Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Loar Holdings Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:LOAR" href="/chart/LOAR" aria-label="Advanced Chart" data-rapid_p="444"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="LOAR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="LOAR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="96.89" active="">96.89</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="LOAR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="5.04" active="">+5.04</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="LOAR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.48721" active="">(+5.49%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LOAR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="5.04" data-tstyle="default" active=""><span class="txt-positive">+5.04</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LOAR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.48721" data-tstyle="default" active=""><span class="txt-positive">+5.49%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="LOAR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1312086" active="">1.312M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">525,968 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="LOAR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="9064649728" active="">9.065B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">403.71 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="LOAR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="94.36309" data-tstyle="default" active=""><span class="txt-positive">+94.36%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Strategy Incorporated" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:MSTR" href="/quote/MSTR/" title="Strategy Incorporated" data-rapid_p="445"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">MSTR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Strategy Incorporated" class="leftAlignHeader yf-362rys enableMaxWidth">Strategy Incorporated</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:MSTR" href="/chart/MSTR" aria-label="Advanced Chart" data-rapid_p="446"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="MSTR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="MSTR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="368.71" active="">368.71</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="MSTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="18.369995" active="">+18.37</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="MSTR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.2434764" active="">(+5.24%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MSTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="18.369995" data-tstyle="default" active=""><span class="txt-positive">+18.37</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MSTR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.2434764" data-tstyle="default" active=""><span class="txt-positive">+5.24%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MSTR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="19338560" active="">19.339M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">18.181M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MSTR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="94203559936" active="">94.204B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MSTR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="185.16516" data-tstyle="default" active=""><span class="txt-positive">+185.17%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Reddit, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:RDDT" href="/quote/RDDT/" title="Reddit, Inc." data-rapid_p="447"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">RDDT </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Reddit, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Reddit, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:RDDT" href="/chart/RDDT" aria-label="Advanced Chart" data-rapid_p="448"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="RDDT chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="RDDT" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="118.1" active="">118.10</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="RDDT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="5.85" active="">+5.85</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="RDDT" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.21158" active="">(+5.21%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RDDT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="5.85" data-tstyle="default" active=""><span class="txt-positive">+5.85</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RDDT" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.21158" data-tstyle="default" active=""><span class="txt-positive">+5.21%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RDDT" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="8677643" active="">8.678M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">8.026M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RDDT" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="20306468864" active="">20.306B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RDDT" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="155.18582" data-tstyle="default" active=""><span class="txt-positive">+155.19%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Marex Group plc" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:MRX" href="/quote/MRX/" title="Marex Group plc" data-rapid_p="449"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">MRX </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Marex Group plc" class="leftAlignHeader yf-362rys enableMaxWidth">Marex Group plc</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:MRX" href="/chart/MRX" aria-label="Advanced Chart" data-rapid_p="450"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="MRX chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="MRX" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="42.74" active="">42.74</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="MRX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="2.0600014" active="">+2.06</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="MRX" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.0639167" active="">(+5.06%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MRX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="2.0600014" data-tstyle="default" active=""><span class="txt-positive">+2.06</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MRX" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="5.0639167" data-tstyle="default" active=""><span class="txt-positive">+5.06%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MRX" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1764390" active="">1.764M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">715,036 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MRX" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3110138624" active="">3.11B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">15.71 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MRX" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="120.99275" data-tstyle="default" active=""><span class="txt-positive">+120.99%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Federated Hermes, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:FHI" href="/quote/FHI/" title="Federated Hermes, Inc." data-rapid_p="451"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">FHI </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Federated Hermes, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Federated Hermes, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:FHI" href="/chart/FHI" aria-label="Advanced Chart" data-rapid_p="452"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="FHI chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="FHI" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="40.1" active="">40.10</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="FHI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.8" active="">+1.80</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="FHI" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.69974" active="">(+4.70%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FHI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.8" data-tstyle="default" active=""><span class="txt-positive">+1.80</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FHI" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.69974" data-tstyle="default" active=""><span class="txt-positive">+4.70%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FHI" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1692711" active="">1.693M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">962,709 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FHI" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3250578176" active="">3.251B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">11.17 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FHI" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="22.74258" data-tstyle="default" active=""><span class="txt-positive">+22.74%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Darling Ingredients Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:DAR" href="/quote/DAR/" title="Darling Ingredients Inc." data-rapid_p="453"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">DAR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Darling Ingredients Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Darling Ingredients Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:DAR" href="/chart/DAR" aria-label="Advanced Chart" data-rapid_p="454"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="DAR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="DAR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="31.88" active="">31.88</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="DAR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.43" active="">+1.43</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="DAR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.69622" active="">(+4.70%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="DAR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.43" data-tstyle="default" active=""><span class="txt-positive">+1.43</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="DAR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.69622" data-tstyle="default" active=""><span class="txt-positive">+4.70%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="DAR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="3454963" active="">3.455M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.393M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="DAR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="5041694208" active="">5.042B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">29.79 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="DAR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-27.889616" data-tstyle="default" active=""><span class="txt-negative">-27.89%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Caesars Entertainment, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CZR" href="/quote/CZR/" title="Caesars Entertainment, Inc." data-rapid_p="455"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CZR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Caesars Entertainment, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Caesars Entertainment, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CZR" href="/chart/CZR" aria-label="Advanced Chart" data-rapid_p="456"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CZR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CZR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="28.44" active="">28.44</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="CZR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.2700005" active="">+1.27</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CZR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.674275" active="">(+4.67%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CZR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="1.2700005" data-tstyle="default" active=""><span class="txt-positive">+1.27</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CZR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.674275" data-tstyle="default" active=""><span class="txt-positive">+4.67%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CZR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="5507772" active="">5.508M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">5.823M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CZR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="6029649408" active="">6.03B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CZR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-24.301302" data-tstyle="default" active=""><span class="txt-negative">-24.30%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Select Medical Holdings Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SEM" href="/quote/SEM/" title="Select Medical Holdings Corporation" data-rapid_p="457"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SEM </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Select Medical Holdings Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Select Medical Holdings Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SEM" href="/chart/SEM" aria-label="Advanced Chart" data-rapid_p="458"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SEM chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SEM" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="17.35" active="">17.35</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="SEM" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.77" active="">+0.77</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SEM" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.64415" active="">(+4.64%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SEM" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.77" data-tstyle="default" active=""><span class="txt-positive">+0.77</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SEM" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.64415" data-tstyle="default" active=""><span class="txt-positive">+4.64%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SEM" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1249879" active="">1.25M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">978,478 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SEM" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2237508096" active="">2.238B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">34.02 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SEM" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="15.046799" data-tstyle="default" active=""><span class="txt-positive">+15.05%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Palantir Technologies Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:PLTR" href="/quote/PLTR/" title="Palantir Technologies Inc." data-rapid_p="459"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">PLTR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Palantir Technologies Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Palantir Technologies Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:PLTR" href="/chart/PLTR" aria-label="Advanced Chart" data-rapid_p="460"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="PLTR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="PLTR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="112.78" active="">112.78</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="PLTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="5" active="">+5.00</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="PLTR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.6390796" active="">(+4.64%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PLTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="5" data-tstyle="default" active=""><span class="txt-positive">+5.00</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PLTR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.6390796" data-tstyle="default" active=""><span class="txt-positive">+4.64%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="PLTR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="102566569" active="">102.567M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">111.583M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="PLTR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="253636575232" active="">253.637B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">593.58 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PLTR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="393.99915" data-tstyle="default" active=""><span class="txt-positive">+394.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="SoFi Technologies, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SOFI" href="/quote/SOFI/" title="SoFi Technologies, Inc." data-rapid_p="461"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SOFI </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="SoFi Technologies, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">SoFi Technologies, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SOFI" href="/chart/SOFI" aria-label="Advanced Chart" data-rapid_p="462"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SOFI chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SOFI" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="12.88" active="">12.88</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="SOFI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.5699997" active="">+0.57</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SOFI" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.630379" active="">(+4.63%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SOFI" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.5699997" data-tstyle="default" active=""><span class="txt-positive">+0.57</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SOFI" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.630379" data-tstyle="default" active=""><span class="txt-positive">+4.63%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SOFI" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="70647859" active="">70.648M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">50.663M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SOFI" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="14220808192" active="">14.221B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">33.03 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SOFI" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="82.82469" data-tstyle="default" active=""><span class="txt-positive">+82.82%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Zeta Global Holdings Corp." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ZETA" href="/quote/ZETA/" title="Zeta Global Holdings Corp." data-rapid_p="463"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ZETA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Zeta Global Holdings Corp." class="leftAlignHeader yf-362rys enableMaxWidth">Zeta Global Holdings Corp.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ZETA" href="/chart/ZETA" aria-label="Advanced Chart" data-rapid_p="464"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ZETA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ZETA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="13.14" active="">13.14</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="ZETA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.58" active="">+0.58</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ZETA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.61783" active="">(+4.62%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ZETA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="0.58" data-tstyle="default" active=""><span class="txt-positive">+0.58</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ZETA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.61783" data-tstyle="default" active=""><span class="txt-positive">+4.62%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ZETA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="3448196" active="">3.448M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">6.168M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ZETA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2985788928" active="">2.986B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ZETA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="3.955698" data-tstyle="default" active=""><span class="txt-positive">+3.96%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Chipotle Mexican Grill, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CMG" href="/quote/CMG/" title="Chipotle Mexican Grill, Inc." data-rapid_p="465"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CMG </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Chipotle Mexican Grill, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Chipotle Mexican Grill, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CMG" href="/chart/CMG" aria-label="Advanced Chart" data-rapid_p="466"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CMG chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CMG" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="51.78" active="">51.78</fin-streamer> <div class="hide-desktop hide-mw txt-positive"><fin-streamer data-test="colorChange" data-symbol="CMG" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="2.24" active="">+2.24</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CMG" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.52159" active="">(+4.52%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CMG" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="2.24" data-tstyle="default" active=""><span class="txt-positive">+2.24</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CMG" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="4.52159" data-tstyle="default" active=""><span class="txt-positive">+4.52%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CMG" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="26656303" active="">26.656M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">14.171M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CMG" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="69766299648" active="">69.766B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">45.82 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CMG" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-19.332474" data-tstyle="default" active=""><span class="txt-negative">-19.33%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> </tbody> <tfoot class="yf-269l37"><tr class="yf-269l37"> </tr></tfoot></table> </div> </div> <div class="paginationContainer yf-1tdhqb1"><div class="select-dropdown yf-1tdhqb1">Rows per page <div class="container  yf-3h01le"><div style="display: contents; --menu-max-height: var(--select-max-height, 300px);"><div class="menuContainer  yf-33jgs4" style="                    "><button class="tertiary-btn fin-size-small menuBtn rounded rightAlign yf-9i625" data-ylk="elmt:menu;itc:1;elm:inpt;sec:stocks-select;subsec:gainers" aria-haspopup="listbox" aria-controls="menu-13" aria-label="25" type="button" title="25" data-rapid_p="467"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z"></path></svg></div> <span class=" textSelect yf-3h01le">25</span> </button> <div class="dialog-container yf-33jgs4" id="menu-13" aria-hidden="true"></div></div></div></div></div> <div class="total yf-1tdhqb1">1-25 of 64</div> <div class="buttons yf-1tdhqb1"><button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:gainers;elm:arrow;itc:1;slk:first-pg" data-testid="first-page-button" disabled="" aria-label="Goto first page" data-rapid_p="468"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M18.41 16.59 13.82 12l4.59-4.59L17 6l-6 6 6 6zM6 6h2v12H6z"></path></svg></div> </button> <button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:gainers;elm:arrow;itc:1;slk:prev" data-testid="prev-page-button" disabled="" aria-label="Goto previous page" data-rapid_p="469"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M15.41 16.59 10.83 12l4.58-4.59L14 6l-6 6 6 6z"></path></svg></div> </button> <button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:gainers;elm:arrow;itc:1;slk:next" data-testid="next-page-button" aria-label="Goto next page" data-rapid_p="470"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M8.59 16.59 13.17 12 8.59 7.41 10 6l6 6-6 6z"></path></svg></div> </button> <button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:gainers;elm:arrow;itc:1;slk:last-pg" data-testid="last-page-button" aria-label="Goto last page" data-rapid_p="471"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M5.59 7.41 10.18 12l-4.59 4.59L7 18l6-6-6-6zM16 6h2v12h-2z"></path></svg></div> </button></div></div></div> </section>'

# %%
top_losers_html = '<section class="yf-12mq010"><header class="large mb-0 yf-13lpgjv font-condensed"><h2 class="header yf-13lpgjv">Stocks</h2> </header>  <div class="container yf-j24h8w"><nav aria-label="stocks" class=" l1 yf-14syam2"><ul class="nav-list tw-p-0 tw-text-md yf-14syam2" role="menubar" aria-label="stocks menubar"><li role="none" class="yf-14syam2"><a href="/markets/stocks/most-active/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Most%20Active;milestonelink:" class="item yf-14syam2" title="Most Active" data-rapid_p="16" data-v9y="1"> <span class="ellipsis yf-14syam2">Most Active</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/trending/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Trending%20Now;milestonelink:" class="item yf-14syam2" title="Trending Now" data-rapid_p="17" data-v9y="1"> <span class="ellipsis yf-14syam2">Trending Now</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/gainers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Top%20Gainers;milestonelink:" class="item yf-14syam2" title="Top Gainers" data-rapid_p="18" data-v9y="1"> <span class="ellipsis yf-14syam2">Top Gainers</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/losers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:Top%20Losers;milestonelink:" class="item yf-14syam2 selected" title="Top Losers" data-rapid_p="19" data-v9y="1" aria-current="page"> <span class="ellipsis yf-14syam2">Top Losers</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/52-week-gainers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:52%20Week%20Gainers;milestonelink:" class="item yf-14syam2" title="52 Week Gainers" data-rapid_p="20" data-v9y="1"> <span class="ellipsis yf-14syam2">52 Week Gainers</span>   </a> </li><li role="none" class="yf-14syam2"><a href="/markets/stocks/52-week-losers/" role="menuitem" data-ylk="elm:navcat;elmt:link;itc:1;sec:stocks-subtab;slk:52%20Week%20Losers;milestonelink:" class="item yf-14syam2" title="52 Week Losers" data-rapid_p="21" data-v9y="1"> <span class="ellipsis yf-14syam2">52 Week Losers</span>   </a> </li></ul></nav> <div class="controls yf-j24h8w"><fieldset class="switch-group tertiary yf-1qaxug3"><div class="button-switch sz-x-small yf-1sf5ssy"><input type="checkbox" id="swc-crrny03s" data-ylk="subsec:losers;elm:tab;itc:1;sec:stocks-datatable;slk:Table%20View" class="yf-1sf5ssy" value="table" data-rapid_p="22" data-v9y="1"> <label for="swc-crrny03s" class="yf-1sf5ssy">table</label> Table View</div> <div class="button-switch sz-x-small yf-1sf5ssy"><input type="checkbox" id="swc-38ucq526" data-ylk="sec:stocks-heatmap;slk:Heatmap%20View;subsec:losers;elm:tab;itc:1" class="yf-1sf5ssy" value="heatmap" data-rapid_p="23" data-v9y="1"> <label for="swc-38ucq526" class="yf-1sf5ssy">heatmap</label> Heatmap View</div></fieldset> </div> <div class="tableContainer yf-j24h8w"><div class="table-container cs-regular tw-border-none yf-269l37"><table class="yf-269l37 bd"><thead class="yf-269l37"><tr class="yf-269l37"><th class="[&amp;_.symbol]:tw-text-md yf-269l37 so lpin shad"><div class="colCont yf-269l37"> Symbol</div></th><th class="leftAlignHeader yf-269l37 so"><div class="colCont yf-269l37"> Name</div></th><th class=" yf-269l37"><div class="colCont yf-269l37"> <span>&nbsp;</span></div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Price</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Change</div></th><th class="yf-269l37 so sorted"><div class="colCont yf-269l37"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-large yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="m12 8-6 6 1.41 1.41L12 10.83l4.59 4.58L18 14z"></path></svg></div> Change %</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Volume</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Avg Vol (3M)</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> Market Cap</div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> <div class="yf-10yevti"><span>P/E Ratio </span><span>(TTM) </span></div></div></th><th class="yf-269l37 so"><div class="colCont yf-269l37"> <div class="yf-10yevti"><span>52 Wk </span><span>Change % </span></div></div></th><th class=" yf-269l37"><div class="colCont yf-269l37"> 52 Wk Range</div></th> </tr></thead> <tbody><tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Summit Therapeutics Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SMMT" href="/quote/SMMT/" title="Summit Therapeutics Inc." data-rapid_p="552" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SMMT </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Summit Therapeutics Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Summit Therapeutics Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SMMT" href="/chart/SMMT" aria-label="Advanced Chart" data-rapid_p="553" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SMMT chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SMMT" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="23.465" active="">23.47</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="SMMT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-13.235001" active="">-13.24</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SMMT" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-36.062668" active="">(-36.06%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SMMT" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-13.235001" data-tstyle="default" active=""><span class="txt-negative">-13.24</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SMMT" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-36.062668" data-tstyle="default" active=""><span class="txt-negative">-36.06%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SMMT" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="24670509" active="">24.671M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.552M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SMMT" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="27072743424" active="">27.073B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SMMT" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="504.76804" data-tstyle="default" active=""><span class="txt-positive">+504.77%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Saia, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SAIA" href="/quote/SAIA/" title="Saia, Inc." data-rapid_p="554" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SAIA </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Saia, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Saia, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SAIA" href="/chart/SAIA" aria-label="Advanced Chart" data-rapid_p="555" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SAIA chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SAIA" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="245.63" active="">245.63</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="SAIA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-108.59" active="">-108.59</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SAIA" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-30.656088" active="">(-30.66%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SAIA" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-108.59" data-tstyle="default" active=""><span class="txt-negative">-108.59</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SAIA" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-30.656088" data-tstyle="default" active=""><span class="txt-negative">-30.66%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SAIA" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="4569514" active="">4.57M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">643,683 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SAIA" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="9433960448" active="">9.434B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">18.18 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SAIA" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-40.96852" data-tstyle="default" active=""><span class="txt-negative">-40.97%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="AppFolio, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:APPF" href="/quote/APPF/" title="AppFolio, Inc." data-rapid_p="556" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">APPF </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="AppFolio, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">AppFolio, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:APPF" href="/chart/APPF" aria-label="Advanced Chart" data-rapid_p="557" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="APPF chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="APPF" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="192.02" active="">192.02</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="APPF" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-42.62999" active="">-42.63</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="APPF" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-18.167479" active="">(-18.17%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="APPF" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-42.62999" data-tstyle="default" active=""><span class="txt-negative">-42.63</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="APPF" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-18.167479" data-tstyle="default" active=""><span class="txt-negative">-18.17%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="APPF" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="1562035" active="">1.562M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">349,273 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="APPF" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="8542374912" active="">8.542B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">35.82 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="APPF" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-19.336271" data-tstyle="default" active=""><span class="txt-negative">-19.34%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Avantor, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:AVTR" href="/quote/AVTR/" title="Avantor, Inc." data-rapid_p="558" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">AVTR </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Avantor, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Avantor, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:AVTR" href="/chart/AVTR" aria-label="Advanced Chart" data-rapid_p="559" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="AVTR chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="AVTR" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="12.93" active="">12.93</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="AVTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-2.57" active="">-2.57</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="AVTR" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-16.5806" active="">(-16.58%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AVTR" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-2.57" data-tstyle="default" active=""><span class="txt-negative">-2.57</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AVTR" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-16.5806" data-tstyle="default" active=""><span class="txt-negative">-16.58%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AVTR" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="42755525" active="">42.756M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">9.166M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AVTR" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="10562038784" active="">10.562B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">12.43 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AVTR" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-46.303986" data-tstyle="default" active=""><span class="txt-negative">-46.30%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Kinsale Capital Group, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:KNSL" href="/quote/KNSL/" title="Kinsale Capital Group, Inc." data-rapid_p="560" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">KNSL </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Kinsale Capital Group, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Kinsale Capital Group, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:KNSL" href="/chart/KNSL" aria-label="Advanced Chart" data-rapid_p="561" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="KNSL chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="KNSL" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="419.99" active="">419.99</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="KNSL" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-81.98" active="">-81.98</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="KNSL" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-16.3317" active="">(-16.33%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="KNSL" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-81.98" data-tstyle="default" active=""><span class="txt-negative">-81.98</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="KNSL" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-16.3317" data-tstyle="default" active=""><span class="txt-negative">-16.33%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="KNSL" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="945872" active="">945,872</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">201,603 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="KNSL" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="11699744768" active="">11.7B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">24.15 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="KNSL" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="17.315638" data-tstyle="default" active=""><span class="txt-positive">+17.32%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="BioNTech SE" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:BNTX" href="/quote/BNTX/" title="BioNTech SE" data-rapid_p="562" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">BNTX </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="BioNTech SE" class="leftAlignHeader yf-362rys enableMaxWidth">BioNTech SE</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:BNTX" href="/chart/BNTX" aria-label="Advanced Chart" data-rapid_p="563" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="BNTX chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="BNTX" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="102.02" active="">102.02</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="BNTX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-18.520004" active="">-18.52</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="BNTX" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-15.364199" active="">(-15.36%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="BNTX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-18.520004" data-tstyle="default" active=""><span class="txt-negative">-18.52</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="BNTX" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-15.364199" data-tstyle="default" active=""><span class="txt-negative">-15.36%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="BNTX" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="6438866" active="">6.439M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.045M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="BNTX" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="28976943104" active="">28.977B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="BNTX" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="15.997732" data-tstyle="default" active=""><span class="txt-positive">+16.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Biohaven Ltd." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:BHVN" href="/quote/BHVN/" title="Biohaven Ltd." data-rapid_p="564" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">BHVN </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Biohaven Ltd." class="leftAlignHeader yf-362rys enableMaxWidth">Biohaven Ltd.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:BHVN" href="/chart/BHVN" aria-label="Advanced Chart" data-rapid_p="565" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="BHVN chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="BHVN" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="19.84" active="">19.84</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="BHVN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-3.56" active="">-3.56</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="BHVN" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-15.2137" active="">(-15.21%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="BHVN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-3.56" data-tstyle="default" active=""><span class="txt-negative">-3.56</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="BHVN" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-15.2137" data-tstyle="default" active=""><span class="txt-negative">-15.21%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="BHVN" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="6163495" active="">6.163M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.349M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="BHVN" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2388319488" active="">2.388B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="BHVN" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-50.1883" data-tstyle="default" active=""><span class="txt-negative">-50.19%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Erie Indemnity Company" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ERIE" href="/quote/ERIE/" title="Erie Indemnity Company" data-rapid_p="566" data-v9y="1"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ERIE </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Erie Indemnity Company" class="leftAlignHeader yf-362rys enableMaxWidth">Erie Indemnity Company</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ERIE" href="/chart/ERIE" aria-label="Advanced Chart" data-rapid_p="567" data-v9y="1"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ERIE chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ERIE" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="361.85" active="">361.85</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="ERIE" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-46.880005" active="">-46.88</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ERIE" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-11.469676" active="">(-11.47%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ERIE" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-46.880005" data-tstyle="default" active=""><span class="txt-negative">-46.88</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ERIE" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-11.469676" data-tstyle="default" active=""><span class="txt-negative">-11.47%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ERIE" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="326444" active="">326,444</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">165,760 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ERIE" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="21372452864" active="">21.372B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">30.77 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ERIE" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-4.4140935" data-tstyle="default" active=""><span class="txt-negative">-4.41%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="T-Mobile US, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:TMUS" href="/quote/TMUS/" title="T-Mobile US, Inc." data-rapid_p="568"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">TMUS </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="T-Mobile US, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">T-Mobile US, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:TMUS" href="/chart/TMUS" aria-label="Advanced Chart" data-rapid_p="569"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="TMUS chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="TMUS" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="232.77" active="">232.77</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="TMUS" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-29.409988" active="">-29.41</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="TMUS" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-11.21748" active="">(-11.22%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TMUS" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-29.409988" data-tstyle="default" active=""><span class="txt-negative">-29.41</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TMUS" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-11.21748" data-tstyle="default" active=""><span class="txt-negative">-11.22%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TMUS" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="13561361" active="">13.561M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">4.462M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TMUS" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="298008444928" active="">298.008B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">22.73 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TMUS" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="41.716896" data-tstyle="default" active=""><span class="txt-positive">+41.72%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Aon plc" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:AON" href="/quote/AON/" title="Aon plc" data-rapid_p="570"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">AON </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Aon plc" class="leftAlignHeader yf-362rys enableMaxWidth">Aon plc</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:AON" href="/chart/AON" aria-label="Advanced Chart" data-rapid_p="571"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="AON chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="AON" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="335.85" active="">335.85</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="AON" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-29.2" active="">-29.20</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="AON" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.9989" active="">(-8.00%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AON" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-29.2" data-tstyle="default" active=""><span class="txt-negative">-29.20</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AON" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.9989" data-tstyle="default" active=""><span class="txt-negative">-8.00%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AON" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="5317648" active="">5.318M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.384M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AON" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="78851194880" active="">78.851B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">26.89 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AON" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="19.502556" data-tstyle="default" active=""><span class="txt-positive">+19.50%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Old Dominion Freight Line, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:ODFL" href="/quote/ODFL/" title="Old Dominion Freight Line, Inc." data-rapid_p="572"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">ODFL </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Old Dominion Freight Line, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Old Dominion Freight Line, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:ODFL" href="/chart/ODFL" aria-label="Advanced Chart" data-rapid_p="573"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="ODFL chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="ODFL" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="146.74" active="">146.74</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="ODFL" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-12.159988" active="">-12.16</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="ODFL" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.6526046" active="">(-7.65%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ODFL" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-12.159988" data-tstyle="default" active=""><span class="txt-negative">-12.16</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ODFL" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.6526046" data-tstyle="default" active=""><span class="txt-negative">-7.65%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ODFL" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="4090651" active="">4.091M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.024M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="ODFL" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="33710141440" active="">33.71B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">27.53 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="ODFL" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-20.353884" data-tstyle="default" active=""><span class="txt-negative">-20.35%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Pony AI Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:PONY" href="/quote/PONY/" title="Pony AI Inc." data-rapid_p="574"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">PONY </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Pony AI Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Pony AI Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:PONY" href="/chart/PONY" aria-label="Advanced Chart" data-rapid_p="575"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="PONY chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="PONY" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="7.01" active="">7.01</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="PONY" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.55999994" active="">-0.56</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="PONY" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.397621" active="">(-7.40%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PONY" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.55999994" data-tstyle="default" active=""><span class="txt-negative">-0.56</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PONY" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.397621" data-tstyle="default" active=""><span class="txt-negative">-7.40%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="PONY" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="39833677" active="">39.834M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">2.986M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="PONY" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2641641472" active="">2.642B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="PONY" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-41.583336" data-tstyle="default" active=""><span class="txt-negative">-41.58%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="HUTCHMED (China) Limited" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:HCM" href="/quote/HCM/" title="HUTCHMED (China) Limited" data-rapid_p="576"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">HCM </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="HUTCHMED (China) Limited" class="leftAlignHeader yf-362rys enableMaxWidth">HUTCHMED (China) Limited</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:HCM" href="/chart/HCM" aria-label="Advanced Chart" data-rapid_p="577"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="HCM chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="HCM" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="14.61" active="">14.61</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="HCM" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-1.1300001" active="">-1.13</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="HCM" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.179162" active="">(-7.18%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="HCM" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-1.1300001" data-tstyle="default" active=""><span class="txt-negative">-1.13</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="HCM" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.179162" data-tstyle="default" active=""><span class="txt-negative">-7.18%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="HCM" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="138059" active="">138,059</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">98,016 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="HCM" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="2687319296" active="">2.687B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">73.05 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="HCM" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-22.739292" data-tstyle="default" active=""><span class="txt-negative">-22.74%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="XPO, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:XPO" href="/quote/XPO/" title="XPO, Inc." data-rapid_p="578"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">XPO </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="XPO, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">XPO, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:XPO" href="/chart/XPO" aria-label="Advanced Chart" data-rapid_p="579"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="XPO chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="XPO" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="96.42" active="">96.42</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="XPO" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-7.3" active="">-7.30</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="XPO" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.03818" active="">(-7.04%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="XPO" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-7.3" data-tstyle="default" active=""><span class="txt-negative">-7.30</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="XPO" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-7.03818" data-tstyle="default" active=""><span class="txt-negative">-7.04%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="XPO" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="3939521" active="">3.94M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.807M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="XPO" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="12216895488" active="">12.217B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">29.85 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="XPO" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-12.9154625" data-tstyle="default" active=""><span class="txt-negative">-12.92%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Ryan Specialty Holdings, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:RYAN" href="/quote/RYAN/" title="Ryan Specialty Holdings, Inc." data-rapid_p="580"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">RYAN </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Ryan Specialty Holdings, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Ryan Specialty Holdings, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:RYAN" href="/chart/RYAN" aria-label="Advanced Chart" data-rapid_p="581"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="RYAN chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="RYAN" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="64.85" active="">64.85</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="RYAN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-4.73" active="">-4.73</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="RYAN" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.79794" active="">(-6.80%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RYAN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-4.73" data-tstyle="default" active=""><span class="txt-negative">-4.73</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RYAN" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.79794" data-tstyle="default" active=""><span class="txt-negative">-6.80%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RYAN" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2281713" active="">2.282M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.024M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="RYAN" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="18256506880" active="">18.257B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">91.34 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="RYAN" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="32.158134" data-tstyle="default" active=""><span class="txt-positive">+32.16%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Amarin Corporation plc" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:AMRN" href="/quote/AMRN/" title="Amarin Corporation plc" data-rapid_p="582"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">AMRN </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Amarin Corporation plc" class="leftAlignHeader yf-362rys enableMaxWidth">Amarin Corporation plc</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:AMRN" href="/chart/AMRN" aria-label="Advanced Chart" data-rapid_p="583"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="AMRN chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="AMRN" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="10.43" active="">10.43</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="AMRN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.75" active="">-0.75</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="AMRN" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.7084074" active="">(-6.71%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AMRN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-0.75" data-tstyle="default" active=""><span class="txt-negative">-0.75</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AMRN" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.7084074" data-tstyle="default" active=""><span class="txt-negative">-6.71%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AMRN" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="56186" active="">56,186</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">89,018 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="AMRN" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="231531408" active="">231.531M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="AMRN" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-40.738636" data-tstyle="default" active=""><span class="txt-negative">-40.74%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Intel Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:INTC" href="/quote/INTC/" title="Intel Corporation" data-rapid_p="584"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">INTC </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Intel Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Intel Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:INTC" href="/chart/INTC" aria-label="Advanced Chart" data-rapid_p="585"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="INTC chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="INTC" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="20.05" active="">20.05</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="INTC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-1.4400005" active="">-1.44</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="INTC" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.7007937" active="">(-6.70%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="INTC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-1.4400005" data-tstyle="default" active=""><span class="txt-negative">-1.44</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="INTC" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.7007937" data-tstyle="default" active=""><span class="txt-negative">-6.70%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="INTC" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="147711174" active="">147.711M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">114.981M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="INTC" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="93709082624" active="">93.709B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="INTC" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-36.065056" data-tstyle="default" active=""><span class="txt-negative">-36.07%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Eastern Bankshares, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:EBC" href="/quote/EBC/" title="Eastern Bankshares, Inc." data-rapid_p="586"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">EBC </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Eastern Bankshares, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Eastern Bankshares, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:EBC" href="/chart/EBC" aria-label="Advanced Chart" data-rapid_p="587"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="EBC chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="EBC" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="14.77" active="">14.77</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="EBC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-1.0199995" active="">-1.02</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="EBC" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.4597816" active="">(-6.46%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EBC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-1.0199995" data-tstyle="default" active=""><span class="txt-negative">-1.02</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EBC" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.4597816" data-tstyle="default" active=""><span class="txt-negative">-6.46%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EBC" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="4053781" active="">4.054M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.274M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EBC" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="3137842432" active="">3.138B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EBC" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="15.210605" data-tstyle="default" active=""><span class="txt-positive">+15.21%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Futu Holdings Limited" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:FUTU" href="/quote/FUTU/" title="Futu Holdings Limited" data-rapid_p="588"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">FUTU </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Futu Holdings Limited" class="leftAlignHeader yf-362rys enableMaxWidth">Futu Holdings Limited</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:FUTU" href="/chart/FUTU" aria-label="Advanced Chart" data-rapid_p="589"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="FUTU chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="FUTU" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="87.85" active="">87.85</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="FUTU" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-6.040001" active="">-6.04</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="FUTU" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.4330606" active="">(-6.43%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FUTU" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-6.040001" data-tstyle="default" active=""><span class="txt-negative">-6.04</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FUTU" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.4330606" data-tstyle="default" active=""><span class="txt-negative">-6.43%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FUTU" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="5035965" active="">5.036M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.258M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="FUTU" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="13072079872" active="">13.072B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">17.53 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="FUTU" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="34.57414" data-tstyle="default" active=""><span class="txt-positive">+34.57%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Centene Corporation" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:CNC" href="/quote/CNC/" title="Centene Corporation" data-rapid_p="590"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">CNC </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Centene Corporation" class="leftAlignHeader yf-362rys enableMaxWidth">Centene Corporation</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:CNC" href="/chart/CNC" aria-label="Advanced Chart" data-rapid_p="591"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="CNC chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="CNC" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="57.69" active="">57.69</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="CNC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-3.89" active="">-3.89</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="CNC" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.31699" active="">(-6.32%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CNC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-3.89" data-tstyle="default" active=""><span class="txt-negative">-3.89</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CNC" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.31699" data-tstyle="default" active=""><span class="txt-negative">-6.32%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CNC" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="8544170" active="">8.544M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">4.811M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="CNC" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="30547372032" active="">30.547B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">8.51 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="CNC" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-21.861034" data-tstyle="default" active=""><span class="txt-negative">-21.86%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Eastman Chemical Company" data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:EMN" href="/quote/EMN/" title="Eastman Chemical Company" data-rapid_p="592"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">EMN </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Eastman Chemical Company" class="leftAlignHeader yf-362rys enableMaxWidth">Eastman Chemical Company</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:EMN" href="/chart/EMN" aria-label="Advanced Chart" data-rapid_p="593"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="EMN chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="EMN" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="75.84" active="">75.84</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="EMN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-4.98" active="">-4.98</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="EMN" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.16185" active="">(-6.16%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EMN" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-4.98" data-tstyle="default" active=""><span class="txt-negative">-4.98</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EMN" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.16185" data-tstyle="default" active=""><span class="txt-negative">-6.16%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EMN" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="2158051" active="">2.158M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.342M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="EMN" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="9331505152" active="">9.332B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">9.66 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="EMN" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-22.087526" data-tstyle="default" active=""><span class="txt-negative">-22.09%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="MP Materials Corp." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:MP" href="/quote/MP/" title="MP Materials Corp." data-rapid_p="594"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">MP </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="MP Materials Corp." class="leftAlignHeader yf-362rys enableMaxWidth">MP Materials Corp.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:MP" href="/chart/MP" aria-label="Advanced Chart" data-rapid_p="595"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="MP chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="MP" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="24.41" active="">24.41</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="MP" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-1.6" active="">-1.60</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="MP" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.15148" active="">(-6.15%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MP" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-1.6" data-tstyle="default" active=""><span class="txt-negative">-1.60</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MP" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.15148" data-tstyle="default" active=""><span class="txt-negative">-6.15%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MP" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="4377437" active="">4.377M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">5.218M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="MP" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="4251123712" active="">4.251B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">-- </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="MP" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="48.66017" data-tstyle="default" active=""><span class="txt-positive">+48.66%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="SS&amp;C Technologies Holdings, Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SSNC" href="/quote/SSNC/" title="SS&amp;C Technologies Holdings, Inc." data-rapid_p="596"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SSNC </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="SS&amp;C Technologies Holdings, Inc." class="leftAlignHeader yf-362rys enableMaxWidth">SS&amp;C Technologies Holdings, Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SSNC" href="/chart/SSNC" aria-label="Advanced Chart" data-rapid_p="597"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SSNC chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SSNC" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="72.69" active="">72.69</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="SSNC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-4.739998" active="">-4.74</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SSNC" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.1216555" active="">(-6.12%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SSNC" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-4.739998" data-tstyle="default" active=""><span class="txt-negative">-4.74</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SSNC" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-6.1216555" data-tstyle="default" active=""><span class="txt-negative">-6.12%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SSNC" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="4652999" active="">4.653M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">1.611M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SSNC" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="19079235584" active="">19.079B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">22.57 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SSNC" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="17.39341" data-tstyle="default" active=""><span class="txt-positive">+17.39%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="TFI International Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:TFII" href="/quote/TFII/" title="TFI International Inc." data-rapid_p="598"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">TFII </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="TFI International Inc." class="leftAlignHeader yf-362rys enableMaxWidth">TFI International Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:TFII" href="/chart/TFII" aria-label="Advanced Chart" data-rapid_p="599"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="TFII chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="TFII" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="79.84" active="">79.84</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="TFII" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-4.69" active="">-4.69</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="TFII" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-5.54833" active="">(-5.55%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TFII" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-4.69" data-tstyle="default" active=""><span class="txt-negative">-4.69</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TFII" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-5.54833" data-tstyle="default" active=""><span class="txt-negative">-5.55%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TFII" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="704958" active="">704,958</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">576,404 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="TFII" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="7076722176" active="">7.077B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">17.62 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="TFII" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-41.198997" data-tstyle="default" active=""><span class="txt-negative">-41.20%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> <tr class="row yf-269l37"><td class="[&amp;_.symbol]:tw-text-md yf-269l37 lpin shad" style="--_depth: undefined;"><div style="display: contents; --background-color: transparent; --hover-bg-color: transparent; --hover-color: var(--enabled-active-emph); --text-color: var(--enabled-active-emph); --hover-focus-color: var(--hovered-emph-same); --text-decoration: underline;"><span class="ticker-wrapper yf-86iz4a"><a data-testid="table-cell-ticker" class="ticker medium [&amp;_.symbol]:tw-text-md hover noPadding yf-86iz4a" aria-label="Skechers U.S.A., Inc." data-ylk="elm:qte;elmt:link;itc:0;sec:stocks-datatable;slk:SKX" href="/quote/SKX/" title="Skechers U.S.A., Inc." data-rapid_p="600"> <div class="name yf-86iz4a"><span class="symbol yf-86iz4a">SKX </span> </div>  </a> </span></div> </td><td class="leftAlignHeader yf-269l37" style="--_depth: undefined;"><div title="Skechers U.S.A., Inc." class="leftAlignHeader yf-362rys enableMaxWidth">Skechers U.S.A., Inc.</div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class="yf-1rh4oll expandWidth enableMaxWidth"><a class="none-link fin-size-small yf-bwm9iy" data-ylk="elm:chart;elmt:link;itc:0;sec:stocks-datatable;slk:SKX" href="/chart/SKX" aria-label="Advanced Chart" data-rapid_p="601"><figure class=" yf-qqbabn" data-testid="sparkline"><canvas aria-label="SKX chart" class=" yf-qqbabn" width="62" height="25" style="width: 50px; height: 20px;"></canvas></figure> </a></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><div class=""><fin-streamer data-test="change" data-symbol="SKX" data-field="regularMarketPrice" data-trend="none" data-pricehint="2" data-value="47.79" active="">47.79</fin-streamer> <div class="hide-desktop hide-mw txt-negative"><fin-streamer data-test="colorChange" data-symbol="SKX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-2.7" active="">-2.70</fin-streamer> <fin-streamer data-test="colorChange" data-symbol="SKX" data-template="({fmt})" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-5.3476" active="">(-5.35%)</fin-streamer></div></div> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SKX" data-field="regularMarketChange" data-trend="txt" data-pricehint="2" data-value="-2.7" data-tstyle="default" active=""><span class="txt-negative">-2.70</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SKX" data-field="regularMarketChangePercent" data-trend="txt" data-pricehint="2" data-value="-5.3476" data-tstyle="default" active=""><span class="txt-negative">-5.35%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SKX" data-field="regularMarketVolume" data-trend="none" data-pricehint="2" data-value="6381422" active="">6.381M</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">3.343M </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="change" data-symbol="SKX" data-field="marketCap" data-trend="none" data-pricehint="2" data-value="7598514688" active="">7.599B</fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;">11.46 </td><td class=" yf-269l37" style="--_depth: undefined;"><fin-streamer data-test="colorChange" data-symbol="SKX" data-field="fiftyTwoWeekChangePercent" data-trend="txt" data-pricehint="2" data-value="-27.79876" data-tstyle="default" active=""><span class="txt-negative">-27.80%</span></fin-streamer> </td><td class=" yf-269l37" style="--_depth: undefined;"><canvas class="yf-2mvkrb" width="175" height="31" style="width: 140px; height: 25px;"></canvas> </td></tr> </tbody> <tfoot class="yf-269l37"><tr class="yf-269l37"> </tr></tfoot></table> </div> </div> <div class="paginationContainer yf-1tdhqb1"><div class="select-dropdown yf-1tdhqb1">Rows per page <div class="container  yf-3h01le"><div style="display: contents; --menu-max-height: var(--select-max-height, 300px);"><div class="menuContainer  yf-33jgs4" style="                    "><button class="tertiary-btn fin-size-small menuBtn rounded rightAlign yf-9i625" data-ylk="elmt:menu;itc:1;elm:inpt;sec:stocks-select;subsec:losers" aria-haspopup="listbox" aria-controls="menu-59" aria-label="25" type="button" title="25" data-rapid_p="602"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z"></path></svg></div> <span class=" textSelect yf-3h01le">25</span> </button> <div class="dialog-container yf-33jgs4" id="menu-59" aria-hidden="true"></div></div></div></div></div> <div class="total yf-1tdhqb1">1-25 of 85</div> <div class="buttons yf-1tdhqb1"><button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:losers;elm:arrow;itc:1;slk:first-pg" data-testid="first-page-button" disabled="" aria-label="Goto first page" data-rapid_p="603"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M18.41 16.59 13.82 12l4.59-4.59L17 6l-6 6 6 6zM6 6h2v12H6z"></path></svg></div> </button> <button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:losers;elm:arrow;itc:1;slk:prev" data-testid="prev-page-button" disabled="" aria-label="Goto previous page" data-rapid_p="604"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M15.41 16.59 10.83 12l4.58-4.59L14 6l-6 6 6 6z"></path></svg></div> </button> <button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:losers;elm:arrow;itc:1;slk:next" data-testid="next-page-button" aria-label="Goto next page" data-rapid_p="605"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M8.59 16.59 13.17 12 8.59 7.41 10 6l6 6-6 6z"></path></svg></div> </button> <button class="icon-btn fin-size-medium rounded yf-9i625" data-ylk="sec:stocks-select;subsec:losers;elm:arrow;itc:1;slk:last-pg" data-testid="last-page-button" aria-label="Goto last page" data-rapid_p="606"><div aria-hidden="true" class="icon fin-icon inherit-icn sz-medium yf-9qlxtu"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24"><path d="M5.59 7.41 10.18 12l-4.59 4.59L7 18l6-6-6-6zM16 6h2v12h-2z"></path></svg></div> </button></div></div></div> </section>'

# %%
top_gainers_soup = bs4.BeautifulSoup(top_gainers_html)
top_gainers_tics = [tic.text.strip() for tic in top_gainers_soup.find_all('span', class_="symbol yf-86iz4a")]
top_gainers_tics
# Out:
# ['AEXAY',
#  'SXT',
#  'EHC',
#  'LBRDK',
#  'CHTR',
#  'LBRDA',
#  'CORZ',
#  'TSLA',
#  'VRSN',
#  'GSHD',
#  'SHECY',
#  'PENN',
#  'FIX',
#  'LOAR',
#  'MSTR',
#  'RDDT',
#  'MRX',
#  'FHI',
#  'DAR',
#  'CZR',
#  'SEM',
#  'PLTR',
#  'SOFI',
#  'ZETA',
#  'CMG']

# %%
top_losers_soup = bs4.BeautifulSoup(top_losers_html)
top_losers_tics = [tic.text.strip() for tic in top_losers_soup.find_all('span', class_="symbol yf-86iz4a")]
top_losers_tics
# Out:
# ['SMMT',
#  'SAIA',
#  'APPF',
#  'AVTR',
#  'KNSL',
#  'BNTX',
#  'BHVN',
#  'ERIE',
#  'TMUS',
#  'AON',
#  'ODFL',
#  'PONY',
#  'HCM',
#  'XPO',
#  'RYAN',
#  'AMRN',
#  'INTC',
#  'EBC',
#  'FUTU',
#  'CNC',
#  'EMN',
#  'MP',
#  'SSNC',
#  'TFII',
#  'SKX']

# %%
len(_52_week_gainers_tics), len(_52_week_losers_tics), len(top_losers_tics), len(top_gainers_tics)
# Out:
# (25, 25, 25, 25)

# %%
_52_week_gainers_tics+_52_week_losers_tics+top_losers_tics+top_gainers_tics
# Out:
# ['RLLVF',
#  'ASTS',
#  'WGS',
#  'SAFS',
#  'RGTI',
#  'SMMT',
#  'RKLB',
#  'PLTR',
#  'VRNA',
#  'FNMA',
#  'KC',
#  'APP',
#  'FMCC',
#  'ALHC',
#  'ADMA',
#  'IONQ',
#  'EAT',
#  'LB',
#  'TGTX',
#  'CORT',
#  'UI',
#  'HOOD',
#  'MSTR',
#  'CVNA',
#  'XIACF',
#  'AEXAY',
#  'TNXP',
#  'HOPHF',
#  'QXO',
#  'CODQL',
#  'MRNA',
#  'CE',
#  'ACHC',
#  'WFRD',
#  'VKTX',
#  'ATKR',
#  'ELF',
#  'APLS',
#  'STLA',
#  'XNYIF',
#  'CIVI',
#  'RIG',
#  'EL',
#  'SMCI',
#  'OLN',
#  'ENPH',
#  'COTY',
#  'DV',
#  'CLF',
#  'FRGE',
#  'SMMT',
#  'SAIA',
#  'APPF',
#  'AVTR',
#  'KNSL',
#  'BNTX',
#  'BHVN',
#  'ERIE',
#  'TMUS',
#  'AON',
#  'ODFL',
#  'PONY',
#  'HCM',
#  'XPO',
#  'RYAN',
#  'AMRN',
#  'INTC',
#  'EBC',
#  'FUTU',
#  'CNC',
#  'EMN',
#  'MP',
#  'SSNC',
#  'TFII',
#  'SKX',
#  'AEXAY',
#  'SXT',
#  'EHC',
#  'LBRDK',
#  'CHTR',
#  'LBRDA',
#  'CORZ',
#  'TSLA',
#  'VRSN',
#  'GSHD',
#  'SHECY',
#  'PENN',
#  'FIX',
#  'LOAR',
#  'MSTR',
#  'RDDT',
#  'MRX',
#  'FHI',
# ...
