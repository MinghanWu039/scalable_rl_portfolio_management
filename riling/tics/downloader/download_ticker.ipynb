# %%
from download_tic import download_tic

# %%
download_tic('html.txt', "symbol yf-5ogvqh")
# Out:
# ['LOAR',
#  'RBLX',
#  'ZLAB',
#  'TPR',
#  'BTSG',
#  'PLMR',
#  'SNEX',
#  'ATGE',
#  'EXEL',
#  'VIRT',
#  'FTNT',
#  'INTA',
#  'SOUN',
#  'BCKIY',
#  'CLBT',
#  'IAG',
#  'GWRE',
#  'CNK',
#  'SOFI',
#  'AS',
#  'MRCY',
#  'IMBBY',
#  'OKLO',
#  'PM',
#  'NTDOY',
#  'USM',
#  'PTGX',
#  'DASH',
#  'NWSAL',
#  'ERJ',
#  'ROAD',
#  'BYDDY',
#  'BYDDF',
#  'ALNY',
#  'BBAR',
#  'CINSF',
#  'LBRDK',
#  'OSIS',
#  'GSHD',
#  'SITM',
#  'HURN',
#  'TKO',
#  'AU',
#  'GME',
#  'HMY',
#  'VRSN',
#  'AEM',
#  'VST',
#  'LMND',
#  'NET',
#  'TIAOF',
#  'LBRDA',
#  'PRMB',
#  'ULS',
#  'CPRX',
#  'FINV',
#  'MIRM',
#  'SBBTF',
#  'NWG',
#  'Z',
#  'LIF',
#  'ARGX',
#  'WMT',
#  'FICO',
#  'ZG',
#  'MWA',
#  'SLNO',
#  'PLNT',
#  'CALM',
#  'SAP',
#  'THLLY',
#  'T',
#  'JBSAY',
#  'AGI',
#  'MIR',
#  'NTRA',
#  'TBBK',
#  'RCL',
#  'LKNCY',
#  'FFIV',
#  'SYBT',
#  'CPOUF',
#  'MHVIY',
#  'CHEF',
#  'KD',
#  'DB',
#  'ERIC',
#  'HWKN',
#  'CVLT',
#  'DTM',
#  'GILD',
#  'TWLO',
#  'GGAL',
# ...
